# %% [markdown]
# # Motive:
#
# - word embedding 모델 중 문서의 id 를 추가적으로 input 으로 받아 문서 하나를 embedding 하는 doc2vec 모델을 이용했습니다.
#
# - 대학원의 각 연구실, 각 연구실에서 투고한 논문을 개별 문서로 인식했습니다.
#
# - 각 대학원 연구실 문서 (corpus) 는 투고 논문 제목, 논문은 abstract 의 일부분을 corpus 에 포함시켰습니다.
#
# - 이번에는 기술적/시간 문제로 google scholar 상에 노출된 abstract 의 일부분만 크롤링할 수 있었습니다.
#
# - 향후에는 더욱 많은 데이터로 embedding map 만들고, 개별 연구실 벡터를 clustering 혹은 classification 문제에 이용해보고 싶습니다.
#
# # 크롤링:
#
# - 각 연구실의 논문 중 2018년 이전에 투고된 논문만 수동으로 저장한뒤, selenium 을 통해 자동적으로 google scholar 에서 abstract 를 크롤링했습니다.
#
# - 이 과정에 속도향상을 위해 multiprocessing 을 이용했습니다.
#
# - 여러 오류가 발생했는데 예외처리를 제대로 하지 못해 데이터가 제대로 수집되지 않은 논문이 다수 있었습니다.

# %%
#Import all the dependencies
from gensim.models.doc2vec import Doc2Vec, TaggedDocument
from nltk.tokenize import word_tokenize

# %%
import nltk
import pickle

# %% [markdown]
# ### Dictionary for lab.

# %%
label =['dm','scm','polytope','imlab']
dct = {}
for i in range(len(label)):
    dct[i] = label[i]

# %%
with open('corpus.pkl','rb') as file:
    corpus = pickle.load(file)

# %%
corpus = ['.'.join(i) for i in corpus]

# %%
with open('dm_abstract.pkl','rb') as file:
    dm_abstract = pickle.load(file)

# %%
with open('abstract_temp.pkl','rb') as file:
    temp = pickle.load(file)

# %%
abstract = dm_abstract + temp

# %%
abstract
# Out:
# [['… effects (such as news about the macroeconomy or expected asset returns), employer‐specific\ntime fixed effects, investor fixed effects, investor‐level income effects, and time … We conclude in\nSection V by reconciling our results with the disposition effect and discussing …',
#   '… Accelerated Degradation Testing (ADT) combines these two approaches by testing products\nin harsh … failures, may be combined with degradation observations to make inference on product\nlifetimes, as in … The point estimates and quantiles for the failure-time dis- tribution at use …',
#   'Many researches have exploited textual data, such as news, online blogs, and financial\nreports, in order to predict stock price movements effectively. Previous studies formed the\ntask as a classification problem predicting upward or downward movement of stock prices\nfrom text documents. Such an approach, however, may be deemed inappropriate when\ncombined with sentiment analysis. In financial documents, same words may convey different\nsentiments across different sectors; if documents from multiple sectors are learned …',
#   'Word-clustering based document representation approaches have been suggested recently\nto overcome previous limitations such as high dimensionality or loss of innate interpretation;\nthey show higher classification performance than other recent methods. Thus, we present a\nnovel way to combine the advantages of various word-clustering based representation\napproaches. Instead of previous approaches, which represent documents in vector form, we\nrepresent documents in matrix form while concatenate various representation results. And …',
#   'After digitally designing components of vehicles, a design team creates a virtual\nmanufacturing environment that resembles actual manufacturing facilities. During this digital\npre-assembly process, a review team examines each component, and records its problems\nand requirements in part verification reports. Once these reports are delivered to specific\ndesign team responsible for each part, the design team can make appropriate adjustments\nto their designs. This digital pre-assembly process can evaluate and prevent flaws in design …',
#   "The classification of customer-voice data is an important matter in real business since it is\nnecessary for customer-voice data to be delivered to relevant departments and responsible\nindividuals. Additionally, customer-voice data typically includes several novel words, such\nas typo's, informal terms, or exceedingly general words to discriminate between categories\nof customer-voice data. Furthermore, noisy data often has a negative effect on the\nclassification task. In this study, advanced novelty detection method is proposed to utilize …",
#   'The term user segmentation refers to classifying users into groups depending on their\nspecific needs, characteristics, or behaviors. It is a key element of product development and\nmarketing in many industries, such as the smartphone industry, which employs user\nsegmentation to gather information about usage logs, to produce new products for such\nspecific groups of users. However, previous studies on smartphone user segmentation have\nbeen primarily based on demographics and reported usage, which are inherently subjective …',
#   'Industry classification has served as an important tool for sector analysis in capital market\nresearch. Most of the existing classification schemes that are commonly used in academia or\nindustry research require human input in the process of its design and construction.\nBecause compilation and maintenance of such schemes demand comprehensive domain\nknowledge, it is highly costly and exhaustively time-consuming to update them to correctly\nreflect the fast-changing trends of the market. In addition, due to its subjective nature …',
#   'This paper proposes a novel framework for inducing a functional relationship between\nmanufacturing data, inspection data and after-sales service data via machine learning-\nbased anomaly detection algorithms and data integration, and the proposed framework can\ndetect defective engines with good performance.',
#   'Two document representation methods are mainly used in solving text mining problems.\nKnown for its intuitive and simple interpretability, the bag-of-words method represents a\ndocument vector by its word frequencies. However, this method suffers from the curse of\ndimensionality, and fails to preserve accurate proximity information when the number of\nunique words increases. Furthermore, this method assumes every word to be independent,\ndisregarding the impact of semantically similar words on preserving document proximity. On …',
#   'The medical care for patients with type 2 diabetes generally involves ingestion of oral\nhypoglycemic agents in order to lower their glucose level. When predicting the result of the\nmedication using a classification approach, high prediction accuracy of the classifier is\nessential because of high misclassification costs. The application of a reject option to this\napproach supports more accurate prediction, allowing for human experts to examine when\nthe classifier is unreliable to predict. In this paper, we propose a reject option framework …',
#   'Analyzing the causal relationships for failures of industrial products is necessary for\nmanufacturers to prevent the occurrence of failures and enhance customer satisfaction. The\ndata collected from each of the production and customer divisions can be a fruitful source for\nfailure analysis. In this paper, we present a data mining process for efficient failure analysis\nof industrial products by a mashup of data collected from both divisions. The process\nconsists of four main steps: problem definition, preprocessing, modeling, and visualization …',
#   'Abstract Copper-clad laminate (CCL), the key material for printed circuit board production, is\nused in various electronic products; thereby, the demand for CCL is on the rise. The process\nof CCL manufacturing occurs in three phases: treating, lay-up, and pressing, while the\nprocess with the largest influence on quality control is the treating. For effective quality\ncontrol, the treating process requires intermediate inspection for three important quality\nfactors: treated weight, minimum viscosity, and gel time. However, a manual inspection …',
#   '… The previous subsections present methods for obtaining more accurate probability estimates\nfrom a decision tree … Therefore, we compare below the ac- curacy of probability estimates obtained\nusing the C4.5 en … To obtain a lift chart, we first sort the examples in descending order …',
#   'Box-office forecasting is a challenging but important task for movie distributors in their\ndecision making process. Many previous studies have tried to determine a way to accurately\npredict the box-office, but the results reported have not been satisfactory for two main\nreasons:(1) lack of variable diversity and (2) simplicity of forecasting algorithms. Although\nthe importance of word-of-mouth (WOM) has consistently emphasized in past studies, only\nsummarized information, such as volume or valence of user ratings is commonly used. In …',
#   'Virtual metrology (VM) has been successfully applied to semiconductor manufacturing as an\nefficient way of achieving wafer-to-wafer quality control. VM involves the estimation of\nmetrology variables of wafer inspection using a prediction model trained with process\nparameters and measurements prior to the actual implementation of metrology. VM\nmodeling should incorporate a number of process parameters and measurements collected\nfrom each piece of process equipment, which results in a greater number of input variables …',
#   'We develop multi-class financial misstatement detection models to detect misstatements\nwith fraud intention. Hennes, Leone and Miller (2008) conducted a post-event analysis of\nfinancial restatements and classified restatements as intentional or unintentional. Using their\nresults (along with non-misstated firms) in the form of a three-class target variable, we\ndevelop three multi-class classifiers, multinomial logistic regression, support vector machine,\nand Bayesian networks, as predictive tools to detect and classify misstatements according to …',
#   'Dataset size continues to increase and data are being collected from numerous\napplications. Because collecting labeled data is expensive and time consuming, the amount\nof unlabeled data is increasing. Semi-supervised learning (SSL) has been proposed to\nimprove conventional supervised learning methods by training from both unlabeled and\nlabeled data. In contrast to classification problems, the estimation of labels for unlabeled\ndata presents added uncertainty for regression problems. In this paper, a semi-supervised …',
#   'Commercial and residential buildings account for 40% of total energy usage in the United\nSates. Efforts have been made to better manage energy through the implementation of\nbuilding energy management systems. In particular, heating, ventilating, and air conditioning\nconsume 50% of energy used in buildings. The system air-conditioner, an individually as\nwell as centrally controlled HVAC system, is widely used across Asia. As energy cost\nincreases, building managers often take building-wide energy saving measures, such as …',
#   'In shipbuilding, the man-hour is a unit widely used for production planning, with systematic\nprediction of man-hour taking greater importance in cost reduction. However, as the man-\nhours are predicted by experts at shipyards, existing methods have often resulted in\nincorrect predictions and cost significant amount of time. There have been several attempts\nmade by many researchers to overcome such problems resulting from prediction by experts.\nYet, their approaches considered only a limited number of factors such as ship …',
#   'A commonly used strategy for solving a multi-class classification problem is to decompose\nthe original problem into several binary subproblems. The recently proposed method,\ndiversified one-against-one (DOAO), constructs a one-against-one classifier by selecting the\nbest classifier for each class pair from the set of heterogeneous base classifiers. It was found\nto yield better classification accuracy than other one-against-one classifiers that are based\non individual classification algorithms. This paper presents a novel method, called optimally …',
#   'In semiconductor manufacturing, wafer fabrication is followed by chip assembly where\nindividual dies are assembled as a packaged chip. In between, dies are tested in terms of\ntheir electrical properties and those which fail to pass the “wafer test” are filtered out.\nHowever, some faulty dies pass the test and cause a packaged chip to fail in the final test.\nThe inaccuracy of the wafer test leads to waste in manufacturing time and cost. In this paper,\nwe propose to predict the result of the final test at the die-level before assembly using wafer …',
#   'The Republic of Korea Armed Forces includes maladjusted conscripts such as the mentally\nill, the suicidal, the imprisoned, and those determined by the military commander to be\nmaladjusted. To counteract these problems, it is necessary to identify the maladjusted\nconscripts to determine who among them would qualify for exemption from active military\nservice or need special attention. We use the Military Personality Inventory (MPI) to make\nthis prediction. Such a prediction presents a kind of class imbalance and class overlap …',
#   'In this paper, a multi-class classification method based on heterogeneous ensemble of one-\nclass classifiers is proposed. The proposed method consists of two phases: training\nheterogeneous one-class classifiers for each class using various one-class classification\nalgorithms, and constructing an ensemble by combining the base classifiers using multi-\nresponse linear regression-based stacking. The use of various classification algorithms\ncontributes towards increasing the diversity of the ensemble, while stacking resolves the …',
#   'The existing multi-class classification algorithms based on support vector machine (SVM)\ngenerally decompose the original problem into smaller subproblems. However, the\ndecomposition approach raises the problems of unreliable and unbalanced training of\nindividual classifiers. The aim of this work is to alleviate these problems. In this paper, a\nnovel multi-class classification algorithm based on one-class SVM is presented. The\ndistinguishing point of our proposed algorithm is that the algorithm solves a one-class …',
#   'Keystroke dynamics, which refers to the typing pattern of an individual, has been highlighted\nas a practical behavioral biometric feature that does not require any additional recognition\ndevice for strengthening user authentication or identification. However, research in the area\nof keystroke dynamics-based user authentication (KDA) has been primarily focused only on\nthe short predefined text, such as identification (ID) and password, typed on a traditional\npersonal computer (PC) keyboard. In this paper, we aim to explore the extendability of KDA …',
#   'The treatment of patients with type 2 diabetes is mostly based on drug therapies, aiming at\nmanaging glucose levels appropriately. As the number of patients with type 2 diabetes\ncontinually increases worldwide, predicting drug treatment failure becomes an important\nissue. Support vector machine (SVM) can be a good method for the anti-diabetic drug failure\nprediction problem; however, it is difficult to train SVM on large-scale medical datasets\ndirectly because of its high training time complexity O (N 3). To address the limitation, we …',
#   'In this paper, we propose a method to optimize the product performance instantly by utilizing\nthe internal voltage trimming circuit for Dynamic Random Access Memory (DRAM) memory.\nSpecifically, we first define the verification wafer as the internal voltage characteristics using\nthe clustering technique. Second, the optimized voltage conditions are applied to a normal\nwafer being matched with a verification wafer. The proposed method makes the ability to\napply a different voltage trimming condition for each dies internal voltage circuit depending …',
#   'The explosive growth of the world-wide-web and the emergence of e-commerce has led to\nthe development of recommender systems. Recommender systems are personalized\ninformation filtering used to identify a set of items that will be of interest to a certain user. This …',
#   'Online advertisers who want their website to be shown in the web search pages need to bid\nfor relevant keywords. Selecting such keywords in advertising is challenging because they\nneed to find relevant keywords of different click volumes and costs. Recent works focused on\nmerely generating a list of words by using semantic or statistical methodologies. However,\nlimited previous studies do not guarantee that those keywords will be used by customers\nand subsequently provide large traffic volume with lower costs. In this study, we propose a …',
#   'Virtual metrology (VM) has been applied to semiconductor manufacturing processes for the\nquality management of wafers. However, noises included in training datasets degrade the\nperformance of VM, which is a key obstacle to the application of VM in real-world\nsemiconductor manufacturing processes. In this paper, we develop a VM dataset\nconstruction method by identifying and removing noises. We define noises by considering\nboth input and output variables and classify noises into fault detection and classification …',
#   'For the one-against-one approach, all the binary classifiers that form a one-against-one\nclassifier should be sufficiently competent. If some of the classifiers are not competent, the\nconsequences might be invalid classification results. To address the problem, we propose\ndiversified one-against-one (DOAO) method that seeks to find the best classification\nalgorithm for each class pair when applying the one-against-one approach to multi-class\nclassification problems. Applying the proposed method makes various classification …',
#   '… systems, including Japanese (Kobayasi, Tokumaga, and Tanaka 1994), Korean (Yun, Lee … to\nthe Frequency Dictionary of Modern Chinese (Beijing Language Institute 1986 … 4.1 Setup of the\nExperimental Environment The corpus-based word extraction method described in the …',
#   'The purpose of virtual metrology (VM) in semiconductor manufacturing is to support process\nmonitoring and quality control by predicting the metrological values of every wafer without\nan actual metrology process, based on process sensor data collected during the operation.\nMost VM-based quality control schemes assume that the VM predictions are always\naccurate, which in fact may not be true due to some unexpected variations that can occur\nduring the process. In this paper, therefore, we propose a means of evaluating the reliability …',
#   'Support vector machine (SVM) is a powerful algorithm for classification and regression\nproblems and is widely applied to real-world applications. However, its high computational\nload in the test phase makes it difficult to use in practice. In this paper, we propose hybrid\nneural network (HNN), a method to accelerate an SVM in the test phase by approximating\nthe SVM. The proposed method approximates the SVM using an artificial neural network\n(ANN). The resulting regression function of the ANN replaces the decision function or the …',
#   'The “locally linear reconstruction”(LLR) provides a principled and k-insensitive way to\ndetermine the weights of k-nearest neighbor (k-NN) learning. LLR, however, does not\nprovide a confidence interval for the k neighbors-based reconstruction of a query point,\nwhich is required in many real application domains. Moreover, its fixed linear structure\nmakes the local reconstruction model unstable, resulting in performance fluctuation for\nregressions under different k values. Therefore, we propose a probabilistic local …',
#   'In semiconductor manufacturing processes, sensor data are segmented and summarized in\norder to reduce storage space. This is conventionally done by segmenting the data based\non predefined chamber step information and calculating statistics within the segments.\nHowever, segmentation via chamber steps often do not coincide with actual change points\nin data, which results in suboptimal summarization. This paper proposes a novel framework\nusing abnormal difference and free knot spline with knot removal, to detect actual data …',
#   'Inspection reports, commonly called “punches” in the marine structuring domain, are written\ndocuments about defects or supplementations on marine structures. Analyzing the\ninspection reports improves the construction process for the structure and prevents\nadditional “punches.” This consequently reduces construction delays and supplementary\ncosts. The free-form texts of the reports, however, hinder management from understanding\nthe nature of defects. Therefore, we applied Knowledge Discovery in the Textual Databases …',
#   'This paper discusses the problem of estimating a ballistic trajectory and the launch point by\nusing a trajectory similarity search in a database. The major difficulty of this problem is that\nestimation accuracy is guaranteed only when an identical trajectory exists in the trajectory\ndatabase (TD). Hence, the TD must comprise an impractically great number of trajectories\nfrom various launch points. Authors proposed a simplified trajectory database with a single\nlaunch point and a trajectory similarity search algorithm that decomposes trajectory similarity …',
#   'We propose a new nonparametric multivariate control chart that integrates a novelty score.\nThe proposed control chart uses as its monitoring statistic a hybrid novelty score, calculated\nbased on the distance to local observations as well as on the distance to the convex hull\nconstructed by its neighbors. The control limits of the proposed control chart were\nestablished based on a bootstrap method. A rigorous simulation study was conducted to\nexamine the properties of the proposed control chart under various scenarios and compare …',
#   'Objectives To explore classification rules based on data mining methodologies which are to\nbe used in defining strata in stratified sampling of healthcare providers with improved\nsampling efficiency. Methods We performed k-means clustering to group providers with\nsimilar characteristics, then, constructed decision trees on cluster labels to generate\nstratification rules. We assessed the variance explained by the stratification proposed in this\nstudy and by conventional stratification to evaluate the performance of the sampling design …',
#   'Drawing on the upper-echelons theory and diversity issues, this study examines the\nrelationships between top management team (TMT) organizational tenure, tenure diversity,\nand combat performance. The study is based on of Korea Combat Training Center (KCTC)\nthat is designed for training and evaluation of the battalion combat power. Findings indicate\nthat battalions with higher levels of TMT tenure have a positive effect on combat\nperformance. Tenure diversity of TMT has a negative effect on combat performance. In …',
#   'In the after-assembly block manufacturing process in the shipbuilding industry, domain\nexperts or industrial managers have the following questions regarding the first step in terms\nof reducing the overhead transportation cost due to irregularities not defined in a process\ndesign:“What tasks are bottlenecks?” and “How long do the blocks remain waiting in\nstockyards?” We provide the answers to these two questions. In the process mining\nframework, we propose a method automatically extracting the most frequent task flows from …',
#   'Two-stage response modeling, identifying respondents and then ranking them according to\ntheir expected profit, was proposed in order to increase the profit of direct marketing. For the\nsecond stage of two-stage response modeling, support vector regression (SVR) has been\nsuccessfully employed due to its great generalization performances. However, the training\ncomplexities of SVR have made it difficult to apply to response modeling based on the large\namount of data. In this paper, we propose a pattern selection method called Expected …',
#   'We proposed a kernel-based binary classification algorithm, named support vector class\ndescription (SVCD), which is an extended version of support vector domain description\n(SVDD) for one-class classification. SVCD constructs two compact hyperspheres in the\nfeature space such that each hypersphere includes as many instances as possible of one\nclass, while keeping the instances of the other class away from the sphere. By doing this,\ntwo linearly non-separable classes in the input space can be well distinguished in the …',
#   "The purpose of response modeling for direct marketing is to identify those customers who\nare likely to purchase a campaigned product, based upon customers' behavioral history and\nother information available. Contrary to mass marketing strategy, well-developed response\nmodels used for targeting specific customers can contribute profits to firms by not only\nincreasing revenues, but also lowering marketing costs. Endemic in customer data used for\nresponse modeling is a class imbalance problem: the proportion of respondents is small …",
#   'Since semiconductor manufacturing consists of hundreds of processes, a faulty wafer\ndetection system, which allows for earlier detection of faulty wafers, is required. statistical\nprocess control (SPC) and virtual metrology (VM) have been used to detect faulty wafers.\nHowever, there are some limitations in that SPC requires linear, unimodal and single\nvariable data and VM underestimates the deviations of predictors. In this paper, seven\ndifferent machine learning-based novelty detection methods were employed to detect faulty …',
#   'In semiconductor manufacturing processes, run-to-run (R2R) control is used to improve\nproductivity by adjusting process inputs run by run. A process will be controlled based on\ninformation obtained during or after a process, including metrology values of wafers. Those\nmetrology values, however, are usually available for only a small fraction of sampled wafers.\nIn order to overcome the limitation, one can use virtual metrology (VM) to predict metrology\nvalues of all wafers, based on sensor data from production equipments and actual metrology …',
#   "Response modeling is concerned with identifying potential customers who are likely to\npurchase a promoted product, based on customers' demographic and behavioral data.\nConstructing a response model requires a preliminary campaign result database …",
#   "Account sharing refers to a situation where multiple individuals share a Web site account to\navoid paying a fee or providing personal information. As a result of account sharing, service\nproviders lose revenue, underestimate membership, and have impaired understanding of\ntheir customers. A generic framework for detecting account sharing is proposed, using\nkeystroke dynamics. Starting with the observation that a user's keystroke patterns are\nconsistent and distinct from those of other individuals, it is assumed that each user's …",
#   "Nowadays, the semiconductor manufacturing becomes very complex, consisting of\nhundreds of individual processes. If a faulty wafer is produced in an early stage but detected\nat the last moment, unnecessary resource consumption is unavoidable. Measuring every\nwafer's quality after each process can save resources, but it is unrealistic and impractical\nbecause additional measuring processes put in between each pair of contiguous processes\nsignificantly increase the total production time. Metrology, as is employed for product quality …",
#   'The purpose of novelty detection is to detect (novel) patterns that are not generated by the\nidentical distribution of the normal class. A distance-based novelty detector classifies a new\ndata pattern as “novel” if its distance from “normal” patterns is large. It is intuitive, easy to\nimplement, and fits naturally with incremental learning. Its performance is limited, however,\nbecause it relies only on distance. In this paper, we propose considering topological\nrelations as well. We compare our proposed method with 13 other novelty detectors based …',
#   "Keystroke dynamics-based authentication (KDA) is to verify a user's identity using not only\nthe password but also keystroke dynamics. With a small number of patterns available, data\nquality is of great importance in KDA applications. Recently, the authors have proposed to\nemploy artificial rhythms and tempo cues to improve data quality: consistency and\nuniqueness of typing patterns. This paper examines whether improvement in uniqueness\nand consistency translates into improvement in authentication performance in real-world …",
#   'Recently, mobile devices are used in financial applications such as banking and stock\ntrading. However, unlike desktops and notebook computers, a 4-digit personal identification\nnumber (PIN) is often adopted as the only security mechanism for mobile devices. Because\nof their limited length, PINs are vulnerable to shoulder surfing and systematic trial-and-error\nattacks. This paper reports the effectiveness of user authentication using keystroke dynamics-\nbased authentication (KDA) on mobile devices. We found that a KDA system can be effective …',
#   'Abstract Instance-based learning (IBL), so called memory-based reasoning (MBR), is a\ncommonly used non-parametric learning algorithm. k-nearest neighbor (k-NN) learning is\nthe most popular realization of IBL. Due to its usability and adaptability, k-NN has been\nsuccessfully applied to a wide range of applications. However, in practice, one has to set\nimportant model parameters only empirically: the number of neighbors (k) and weights to\nthose neighbors. In this paper, we propose structured ways to set these parameters, based …',
#   "Keystroke dynamics based user authentication (KDA) can achieve a relatively high\nperformance if a fairly large number of typing patterns are available. It is almost always the\ncase that KDA is combined with password based authentication. Users are often required to\nchange their passwords. When a user changes one's password, however, only a handful of\nnew patterns become available. In a mobile situation, moreover, very short passwords are\nused. Under such a circumstance, the quality of data becomes important. Recently, artificial …",
#   'Abstract Support Vector Machine (SVM) results in a good generalization performance by\nemploying the Structural Risk Minimization (SRM) principle. However, one drawback is O (n\n3) training time complexity. In this paper, we propose a pattern selection method designed\nspecifically for Support Vector Regression (SVR). In SVR training, only a few patterns called\nsupport vectors are used to construct the regression model while other patterns are not used\nat all. The proposed method tries to select patterns which are likely to become support …',
#   "Objective Computerized continuous performance test (CPT) is a widely used diagnostic tool\nfor attention-deficit hyperactivity disorder (ADHD). It measures the number of correctly\ndetected stimuli as well as response times. Typically, when calculating a cut-off score for\ndiscriminating between normal and abnormal, only the normal children's data are collected.\nThen the average and standard deviation of each measure or variable is computed. If any of\nvariables is larger than 2 sigma above the average, that child is diagnosed as abnormal. We …",
#   'Response modeling has become a key factor to direct marketing. In general, there are two\nstages in response modeling. The first stage is to identify respondents from a customer\ndatabase while the second stage is to estimate purchase amounts of the respondents. This\npaper focuses on the second stage where a regression, not a classification, problem is\nsolved. Recently, several non-linear models based on machine learning such as support\nvector machines (SVM) have been applied to response modeling. However, there is a major …',
#   'Response Modeling is concerned with computing the likelihood of a customer to respond to\na marketing campaign. A major problem encountered in response modeling is huge volume\nof data or patterns. The k-NN has been used in various classification problems for its\nsimplicity and ease of implementation. However, it has not been applied to problems for\nwhich fast classification is needed since the classification time rapidly increases as the size\nof reference set increases. In this paper, we propose a clustering-based preprocessing step …',
#   'Keystroke dynamics based authentication (KDA) verifies a user based on the typing pattern.\nDuring enroll, a few typing patterns are provided, which are then used to train a classifier.\nThe typing style of a user is not expected to change. However, sometimes it does change,\nresulting in a high false reject. In order to achieve a better authentication performance, we\npropose to continually retrain classifiers with recent login typing patterns by updating the\ntraining data set. There are two ways to update it. The moving window uses a fixed number …',
#   "In keystroke dynamics-based authentication, novelty detection methods are used since only\nthe valid user's patterns are available when a classifier is first constructed. After a while,\nhowever, impostors' keystroke patterns become available from failed login attempts. We\npropose to employ the retraining framework where a novelty detector is retrained with the\nimpostor patterns to enhance authentication accuracy. In this paper, learning vector\nquantization for novelty detection and support vector data description are retrained with the …",
#   'This paper proposes to use novelty detection approaches to alleviate the class imbalance in\nresponse modeling. Two novelty detectors, one-class support vector machine (1-SVM) and\nlearning vector quantization for novelty detection (LVQ-ND), are compared with binary\nclassifiers for a catalogue mailing task with DMEF4 dataset. The novelty detectors are more\naccurate and more profitable when the response rate is low. When the response rate is\nrelatively high, however, a support vector machine model with modified misclassification …',
#   'The support vector machine (SVM) has been spotlighted in the machine learning community\nbecause of its theoretical soundness and practical performance. When applied to a large\ndata set, however, it requires a large memory and a long time for training. To cope with the\npractical difficulty, we propose a pattern selection algorithm based on neighborhood\nproperties. The idea is to select only the patterns that are likely to be located near the\ndecision boundary. Those patterns are expected to be more informative than the randomly …',
#   'We show that the novelty detection approach is a viable solution to the class imbalance and\nexamine which approach is suitable for different degrees of imbalance. In experiments using\nSVM-based classifiers, when the imbalance is extreme, novelty detectors are more accurate\nthan balanced and unbalanced binary classifiers. However, with a relatively moderate\nimbalance, balanced binary classifiers should be employed. In addition, novelty detectors\nare more effective when the classes have a non-symmetrical class relationship.',
#   'Data imbalance occurs when the number of patterns from a class is much larger than that\nfrom the other class. It often degenerates the classification performance. In this paper, we\npropose an Ensemble of Under-Sampled SVMs or EUS SVMs. We applied the proposed\nmethod to two synthetic and six real data sets and we found that it outperformed other\nmethods, especially when the number of patterns belonging to the minority class is very\nsmall.',
#   'The training time complexity of Support Vector Regression (SVR) is O (N 3). Hence, it takes\nlong time to train a large dataset. In this paper, we propose a pattern selection method to\nreduce the training time of SVR. With multiple bootstrap samples, we estimate ε-tube.\nProbabilities are computed for each pattern to fall inside ε-tube. Those patterns with higher\nprobabilities are selected stochastically. To evaluate the new method, the experiments for 4\ndatasets have been done. The proposed method resulted in the best performance among all …',
#   "Keystroke dynamics-based authentication (KDA) is to verify a user's identification using not\nonly the password but also keystroke patterns. The authors have shown in previous\nresearch that uniqueness and consistency of keystroke patterns are important factors to\nauthentication accuracy and that they can be improved by employing artificial rhythms and\ntempo cues. In this paper, we implement the pause strategy and/or auditory cues for KDA\nand assess their effectiveness using various novelty detectors. Experimental results show …",
#   "In keystroke dynamics based user authentication, an access system utilizes not only a valid\nuser's password, but also his/her typing patterns. Although high performances in terms of\nFAR (False Acceptance Rate) and FRR (False Rejection Rate) have been reported, most\nresearches used a large number of valid users' typing patterns in order to implement\ncomplex algorithms in building a classifier [1]. However, collecting sufficient typing patterns\nto construct a complex classifier is practically impossible. When only a handful of typing …",
#   '… Application of LVQ to novelty detection using outlier training data … Various novelty detection\nmethods have been proposed for these applications (Markou and Singh, 2003a, Markou and …\nTo apply this approach, however, one should be able to estimate or assume explicitly the …',
#   'Ensemble of classifiers is a learning paradigm where many classifiers are jointly used to\nsolve a problem. Research has shown that ensemble is very effective for classification tasks.\nDiversity and accuracy are two basic requirements for the ensemble creation. In this paper,\nwe propose an ensemble creation method based on GA wrapper feature selection.\nPreliminary experimental results on real-world data show that the proposed method is\npromising, especially when the number of training data is limited.',
#   'Abstract Support Vector Machine (SVM) employs Structural Risk Minimization (SRM)\nprinciple to generalize better than conventional machine learning methods employing the\ntraditional Empirical Risk Minimization (ERM) principle. When applying SVM to response\nmodeling in direct marketing, however, one has to deal with the practical difficulties: large\ntraining data, class imbalance and scoring from binary SVM output. For the first difficulty, we\npropose a way to alleviate or solve it through a novel informative sampling. For the latter two …',
#   "In building a response model, determining the inputs to the model has been an important\nissue because of the complexities of the marketing problem and limitations of mental models\nfor decision-making. It is common that the customers' historical purchase data contains many\nirrelevant or redundant features thus result in bad model performance. Furthermore, single\ncomplex models based on feature subset selection may not always report improved\nperformance largely because of overfitting and instability. Ensemble is a widely adopted …",
#   'This paper presents three data mining problems that are often encountered in building a\nresponse model. They are robust modeling, variable selection and data selection.\nRespective algorithmic solutions are given. They are bagging based ensemble, genetic\nalgorithm based wrapper approach and nearest neighbor-based data selection in that order.\nA real world data set from Direct Marketing Educational Foundation, or DMEF4, is used to\nshow their effectiveness. Proposed methods were found to solve the problems in a practical …',
#   'User authentication based on keystroke dynamics is concerned with accepting or rejecting\nsomeone based on the way the person types. A timing vector is composed of the keystroke\nduration times interleaved with the keystroke interval times. Which times or features to use in\na classifier is a classic feature selection problem. Genetic algorithm based wrapper\napproach does not only solve the problem, but also provides a population of “fit” classifiers\nwhich can be used in ensemble. In this paper, we propose to add uniqueness term in the …',
#   "The purpose of this research was to detect the pattern of player's emotional change during\non-line game. By defining data processing technique and analysis method for bio-\nphysiological activity and player's bluffing behavior, the classification of affective attitudes\nduring on-line game was attempted. Bluffing behavior displayed during the game was\nclassified into two dimensions of emotional axis based on prefrontal surface\nelectroencephalographic data. Classified bluffing attitudes were:(1) pleasantness …",
#   "In keystroke dynamics-based authentication, novelty detection methods have been used\nsince only the valid user's patterns are available when a classifier is built. After a while,\nhowever, impostors' keystroke patterns become also available from failed login attempts. We\npropose to retrain the novelty detector with the impostor patterns to enhance the\nperformance. In this paper the support vector data description (SVDD) and the one-class\nlearning vector quantization (1-LVQ) are retrained with the impostor patterns. Experiments …",
#   "Biometrics based user authentication involves collecting user's patterns and then using them\nto determine if a new pattern is similar enough. The quality of the user's patterns is as\nimportant as the quality of the classifier. But, the issue has been ignored in the literature\nsince the popular biometrics are mostly trait based such as finger prints and iris so that its\npattern quality depends on the quality of the input device involved. However, the quality of\nthe user's patterns of behavior based biometric such as keystroke dynamics can be …",
#   'Novelty detection involves identifying novel patterns. They are not usually available during\ntraining. Even if they are, the data quantity imbalance leads to a low classification accuracy\nwhen a supervised learning scheme is employed. Thus, an unsupervised learning scheme …',
#   'If the training pattern set is large, it takes a large memory and a long time to train support\nvector machine (SVM). Recently, we proposed neighborhood property based pattern\nselection algorithm (NPPS) which selects only the patterns that are likely to be near the\ndecision boundary ahead of SVM training [Proc. of the 7th Pacific-Asia Conference on\nKnowledge Discovery and Data Mining (PAKDD), Lecture Notes in Artificial Intelligence\n(LNAI 2637), Seoul, Korea, pp. 376–387]. NPPS tries to identify those patterns that are likely …',
#   'Identifying customers who are likely to respond to a product offering is an important issue in\ndirect marketing. Response models are typically built from historical purchase data. A\npopular method of choice, logistic regression, is easy to understand and build, but limited in\nthat the model is linear in parameters. Neural networks are nonlinear and have been found\nto improve predictive accuracies for a variety of business applications. Neural networks have\nnot always demonstrated clear supremacy over traditional statistics competitors, largely …',
#   '… Also included are functions that combine model-based hierarchical clustering, EM for mixture\nestimation and the Bayesian Information Criterion (BIC) in comprehensive … Simulation from\nparameterized Gaussian mixtures; … Combining Gaussian mixture components for clustering …',
#   "Password is the most widely used identity verification method in computer security domain.\nHowever, because of its simplicity, it is vulnerable to imposter attacks. Use of keystroke\ndynamics can result in a more secure verification system. Recently, Cho et al.(J Organ\nComput Electron Commerce 10 (2000) 295) proposed autoassociative neural network\napproach, which used only the user's typing patterns, yet reporting a low error rate: 1.0%\nfalse rejection rate (FRR) and 0% false acceptance rate (FAR). However, the previous …",
#   'Training SVM requires large memory and long cpu time when the pattern set is large. To\nalleviate the computational burden in SVM training, we propose a fast preprocessing\nalgorithm which selects only the patterns near the decision boundary. The time complexity of\nthe proposed algorithm is much smaller than that of the naive M 2 algorithm',
#   'Password is the most widely used identity verification method in computer security domain.\nHowever, due to its simplicity, it is vulnerable to imposter attacks. Keystroke dynamics adds\na shield to password. Discriminating imposters from owners is a novelty detection problem.\nRecent research reported good performance of Auto-Associative Multilayer Perceptron\n(AaMLP). However, the 2-layer AaMLP cannot identify nonlinear boundaries, which can\nresult in serious problems in computer security. In this paper, we applied 4-layer AaMLP as …',
#   'Training SVM requires large memory and long cpu time when the pattern set is large. To\nalleviate the computational burden in SVM training, we propose a fast preprocessing\nalgorithm which selects only the patterns near the decision boundary. Preliminary simulation\nresults were promising: Up to two orders of magnitude, training time reduction was achieved\nincluding the preprocessing, without any loss in classification accuracies.',
#   'Abstract The previous ESP (Ensemble Streamflow Prediction) studies conducted in Korea\nreported that the modeling error is a major source of the ESP forecast error in winter and\nspring (ie dry seasons), and thus suggested that improving the rainfall-runoff model would\nbe critical to obtain more accurate probabilistic forecasts with ESP. This study used two\ntypes of Artificial Neural Networks (ANN), such as a Single Neural Network (SNN) and an\nEnsemble Neural Networks (ENN), to improve the simulation capability of the rainfall-runoff …',
#   'We propose a neural network based up-trend detector. An auto-associative neural network\nwas trained with “up-trend” data obtained from the KOSPI 200 future price. It was then used\nto predict an up-trend. Simple investment strategies based on the detector achieved a two\nyear return of 19.8% with no leverage.',
#   'SVMs tend to take a very long time to train with a large data set. If “redundant” patterns are\nidentified and deleted in pre-processing, the training time could be reduced significantly. We\npropose ak-nearest neighbors (k-NN) based pattern selection method. The method tries to\nselect the patterns that are near the decision boundary and that are correctly labeled. The\nsimulations over synthetic data sets showed promising results:(1) By converting a non-\nseparable problem to a separable one, the search for an optimal error tolerance parameter …',
#   "We propose Observational Learning Algorithm (OLA), an ensemble learning algorithm with\nT and O steps alternating. In the T-step, an ensemble of networks is trained with a training\ndata set. In the O-step,'virtual'data are generated in which each target pattern is determined\nby observing the member networks' output for the input pattern. These virtual data are added\nto the training data and the two steps are repeatedly executed. The virtual data was found to\nplay the role of a regularisation term as well as that of temporary hints having the auxiliary …",
#   'Recently, a combined approach of bagging (bootstrap aggregating) and noise addition was\nproposed and shown to result in a significantly improved generalization performance. But,\nthe level of noise introduced, a crucial factor, was determined by trial and error. The\nprocedure is not only ad hoc but also time consuming since bagging involves training a\ncommittee of networks. Here we propose a principled procedure of computing the level of\nnoise, which is also computationally less expensive. The idea comes from kernel density …',
#   'Observational learning algorithm is an ensemble algorithm where each network is initially\ntrained with a bootstrapped data set and virtual data are generated from the ensemble for\ntraining. Here we propose a modular OLA approach where the original training set is\npartitioned into clusters and then each network is instead trained with one of the clusters.\nNetworks are combined with different weighting factors now that are inversely proportional to\nthe distance from the input vector to the cluster centers. Comparison with bagging and …',
#   'We propose a neural network based “left shoulder” detector. The auto-associative neural\nnetwork was trained with the “lelt sliouldcr” patterns obtained from the Korea Composite\nStock Price Index, and then tested out-of-sample with a reasonably good result. A\nhypothetical investment strategy besed on the detector achieved a return of 124% in\ncomparison with 39% return from a buy and hold strategy.',
# ...
#   'Although pricing fraud is an important issue for improving service quality of online shopping\nmalls, research on automatic fraud detection has been limited. In this paper, we propose an\nunsupervised learning method based on a finite mixture model to identify pricing frauds. We\nconsider two states, normal and fraud, for each item according to whether an item\ndescription is relevant to its price by utilizing the known number of item clusters. Two states\nof an observed item are modeled as hidden variables, and the proposed models estimate …',
#   'As a storage and retrieval unit of user generated web objects, set has been receiving\nincreased attention recently in information retrieval research community. Set search requires\nrelevant sets to be retrieved to meet information needs of users. It is different from individual\nobject search in terms of content granularity. While a web object itself is not divisible and\nindependent with each other, a set consists of separable objects that are related in some\naspects. This paper proposes a new approach that can effectively measure topical …',
#   'Purpose–Revenue maximization through improving click-throughs is of great importance for\nprice comparison shopping services (PCSSs) whose revenues directly depend on the\nnumber of click-throughs of items in their itemsets. The purpose of this paper is to present an\napproach aiming to maximize the revenue of a PCSS by proposing effective itemset\nconstruction methods that can maximize the click-throughs. Design/methodology/approach–\nThe authors suggest three itemset construction methods, namely naïve method (NM) …',
#   'As social media services such as Twitter and Facebook are gaining popularity, the amount\nof information published from those services is explosively growing. Most of them use feeds\nto facilitate distribution of a huge volume of content they publish. In this context, many users\nsubscribe to feeds to acquire up-to-date information through feed aggregation services, and\nrecent real-time search engines also increasingly utilize feeds to promptly find recent web\ncontent when it is produced. Accordingly, it is necessary for such services to effectively fetch …',
#   'Real-time search engines are increasingly indexing web content using data streams, since a\nnumber of web sources including news and social media sites are now delivering up-to-date\ninformation via streams. Accordingly, it is a crucial challenge for a real-time search engine\nusing data streams to improve index freshness that primarily depends on the latencies\ninvolved during fetching and indexing processes. Retrieval latency is a time lag between\ndocument publication and fetching while indexing latency is a delay required for a fetched …',
#   'Information diffusion analysis in social networks is of significance since it enables us to\ndeeply understand dynamic social interactions among users. In this paper, we introduce\napproaches to discovering information diffusion process in social networks based on\nprocess mining. Process mining techniques are applied from three perspectives: social\nnetwork analysis, process discovery and community recognition. We then present\nexperimental results by using a real-life social network data. The proposed techniques are …',
#   "In this article, we outline a system that relies on a hybrid approach with a simple, yet powerful\nframework that takes advantages from both CBF and CF and uses the characteristics unique\nto the problem of recommending online videos that are socially annotated with tags. 2 In contrast\nto the existing hybrid methods, the proposed approach is based on the implicit users' view-transaction\ndata instead of the explicit ratings data, and uses that data to automatically aggregate tag clouds\n2 for users over time. The constructed tag cloud is then used as a profile to compute the similarity …",
#   'Traditional workflow management systems provide rich capabilities for designing, executing,\nand monitoring well-defined collaborative processes. Yet, for many occasions of\ncollaboration, we do not often have sufficient information about who will participate, what\nactivities people will carry out, and how the entire workflow will change. Accordingly, the\nproblem of managing flexible workflows has been receiving increasing attention during the\nlast decade. This paper presents a novel approach by which collaborative workflows can be …',
#   'In this article, we introduce FeedMil, a stream search engine that attempts to provide topic-focused\nsearches for various live streams from social media such as blogs, microblogs, and community\nchannels. (FeedMil is available as a research prototype at http://feedmil.com.) Our proposed\nsearch engine architecture accounts for the structural and temporal characteristics unique to\nstream search, focusing on the problems of stream relevance judgment and ranking. To address\nthe limitations of the existing stream search engines that merely match feed titles and a …',
#   'One of the most exciting recent developments in web science is social tagging that enables\nusers to easily annotate web content using free form keywords. Well known examples\ninclude Delicious, Flickr, and YouTube which respectively allow users to tag web pages,\nimages, and videos. A tag cloud represents an aggregation of tags to characterize some\nentity of interest, and it has many potential applications particularly in the context of\nmultimedia information retrieval and recommendation. In this paper, we present a novel …',
#   "Blogs are increasingly accepted as a useful means to proliferate a variety of information on\nthe web. As the popularity of blogs grows rapidly, a number of blog search engines have\nappeared recently to help users access and discover blog posts efficiently. Nevertheless,\nexisting approaches tend to focus on ranking the blog posts according to their recency or\npopularity only, leaving the problem of retrieving more topic relevant posts to a user's query\nlargely unexplored. In this paper, we present a novel blog ranking framework, called …",
#   'In this paper, we present a new framework for measuring business performance of mobile\nuser interfaces (UIs). Until now, the performance measurement of mobile UI was mainly to\nassess usability performance. Yet, as mobile phones are increasingly replacing wired\ndevices, stakeholders in mobile phones began to invest a lot of time and money to mobile UI\ndevelopment. As a result, it is desirable that the business performance of mobile UI has to be\nmeasured qualitatively as well as quantitatively. This paper develops a measurement model …',
#   'WorkfloWs describe business processes as coordinated execution of simple activities\ncarried out by human or software applications. Over the past decade, workflow technology\nhas been widely deployed in the domains with processes that have clear coordination\nrequirements, and it has achieved significant commercial success in automating such\nroutine business processes. However, as business environment becomes increasingly\ndynamic, there is a growing need that workflow technology must also support domains …',
#   'Emerging ubiquitous computing network is expected to consist of a variety of heterogeneous\nand distributed devices. While web services technology is increasingly being considered as\na promising solution to support the inter-operability between such heterogeneous devices\nvia well-defined protocol, currently there is no effective framework reported in the literature\nthat can address the problem of coordinating the web services-enabled devices. This paper\nconsiders a ubiquitous computing environment that is comprised of active, autonomous …',
#   'The portfolio management for trading in the stock market poses a challenging stochastic\ncontrol problem of significant commercial interests to finance industry. To date, many\nresearchers have proposed various methods to build an intelligent portfolio management\nsystem that can recommend financial decisions for daily stock trading. Many promising\nresults have been reported from the supervised learning community on the possibility of\nbuilding a profitable trading system. More recently, several studies have shown that even the …',
#   'Business process management systems (BPMSs) are increasingly gaining momentum as a\nsoftware platform on which to define, execute, and track enterprise-wide business\nprocesses. BPMSs promise to facilitate automation, integration, and optimization of business\nprocesses in order to support decision making, increase operational efficiency, and lower\nthe cost of doing business. In spite of the growing popularity, however, realization of the\ngrand vision BPMSs ultimately seek to achieve calls for renewed focus on the holistic …',
#   'Abstract WS-CDL (Web Services Choreography Description Language), a Candidate\nRecommendation from World Wide Web Consortium, facilitates the specification of rules to\ngovern the ordering of message exchanges between web service participants. This paper\nconsiders a computing environment where a mobile client interoperates with a web service\nprovider according to a WS-CDL specification that defines peer-to-peer interactions, and\nproposes a framework through which the client can specify its preference on how …',
#   'Web services are emerging as an effective means for carrying out automated transactions\nbetween multiple business parties. While there are several specific protocols that have been\ndiscussed to address the problem of coordinating web services-enabled business\ntransactions, we consider the tentative hold protocol (THP) that allows the placement of\ntentative holds on business resources prior to actual transactions in order to provide\nincreased flexibility in coordination. In this paper, we present a formal coordination …',
#   'Using web services to expose applications over the Internet is now a widely accepted\npractice. Currently, there are several ongoing efforts that provide ways to effectively\ncompose web services distributed across different organizations. One of the problems\nunderlying the deployment of such composite services on the web, however, is service co-\nallocation that arises when a composite service needs to ensure all the required component\nservices to be available for execution at the same time. Motivated by this, this paper presents …',
#   'Communities play a vital role in online gaming world for promoting sustainability, and with\nthe increasing popularity of multiplayer online games, they are becoming internationalized.\nWhile most online games allow players to communicate and collaborate with virtually any\npeople in the world throughout the game related activities, little has been discussed on the\ncommunication support among the players speaking different languages. In this paper, we\nanalyze the communication methods that can be used to facilitate various types of …',
#   'Web service technology is a representative means of heterogeneous system integration and\ncommunication. Process language standards, such as WS-BPEL and WS-CDL, have\naccelerated the usability of web services in business area. However, recently emerging web\nservice devices in ubiquitous environments still have a difficulty in coordinating their\nprocesses because of the limited computing power and storage. This research proposes a\nframework of event-based process enactment for ubiquitous web service devices. The …',
#   'While web service technology is becoming a de facto standard for integration of business\napplications, it is also rapidly emerging as an effective means for achieving inter-operability\namong the devices in network centric ubiquitous systems. When such a web service\nenabled device engages in a conversation with a service provider, it becomes necessary to\ndefine an interaction logic required between them. For this purpose, one can use a\nchoreography language to specify the rules of engagement between the device and the web …',
#   '抄録 New developments in service-oriented computing allow the creation of Web services-\nenabled business processes that can be defined through the composition of a set of existing\nservices. Recently many proposals have emerged along this line, including BPSS, BPML,\nand BPEL4WS, with little effort spent on the development of systematic methods to\neffectively support composition of partner business processes that dynamically discover and\ninteract with publicly available business processes at runtime. Motivated by this, this paper …',
#   'Computing over the Internet is becoming increasingly popular. With the emerging\ninfrastructures such as computational grids and Web services, it is possible to develop\napplications that support various Internet-wide collaborations through seamlessly\nharnessing appropriate Internet resources. Yet, as Internet computing is becoming\npervasive, it also presents a number of new challenges in designing efficient resource\nallocation protocol that provides clear directives on the acquisition of shared resources. In …',
#   'The emerging Web services are building blocks for creating highly distributed e-Business\napplications, allowing any services to be integrated as long as they are Web-enabled. This\ninteroperability allows businesses to dynamically discover and aggregate a range of\ncomponent services to more easily create value-added composite services. One of the\nproblems underlying the deployment of such composite services on the Web is service co-\nallocation that arises when a composite service needs to ensure all the required component …',
#   'Liveness-enforcing supervisors (LESs) guarantee deadlock-free operations in resource\nallocation systems (RASs). Given the growing emphasis on higher resource utilization and\noperational flexibility, it is greatly desirable to obtain the optimal LES that can provide the\nmaximum behavioral latitude. In general, however, computation of the maximally permissive\nLES is computationally intractable and, accordingly, the class of algebraic LESs has been\nproposed in the literature as a viable suboptimal alternative for various RAS classes. The …',
#   'Although liveness enforcing supervision (LES) of sequential resource allocation systems\n(RAS) is currently a well-established problem in the Discrete Event System literature, all\nprior work on it has addressed the underlying LES synthesis problem under the assumption\nthat the system behavior is totally controllable. The work presented in this paper seeks to\ndevelop correct and scaleable LES for RAS that present uncontrollability with respect to: 1)\nthe timing of some requested resource allocations, ie, these allocations will take place as …',
#   'This paper presents a new distributed real-time control architecture for flexibly automated\nproduction systems. The modelling assumptions underlying the design are driven by, and\nabstract, the structure and operations of the emerging 300 mm semiconductor manufacturing\nfab, one of the most extensively automated environments in contemporary manufacturing.\nThe key element of the controller design itself, which differentiates it from past efforts, is the\ndistribution of the control function to the constituent components of the system shop-floor …',
#   'Considers the deadlock avoidance problem for the class of conjunctive/disjunctive\n(sequential) resource allocation systems (C/D-RAS), which allows for multiple resource\nacquisitions and flexible routings. First, a siphon-based characterization for the liveness of\nPetri nets (PNs) modeling C/D-RAS is developed, and subsequently, this characterization\nfacilitates the development of a polynomial-complexity deadlock avoidance policy (DAP) that\nis appropriate for the considered RAS class. The resulting policy is characterized as C/D …']]

# %%
len(abstract) # abstracts for 4 labs
# Out:
# 4

# %%
#No abstract was crawled for lab. 2 due to error
abstract.pop(2)
# Out:
# []

# %%
#flatten list
abstract = [item for sublist in abstract for item in sublist]

# %%
len(abstract)
# Out:
# 202

# %% [markdown]
# # Preprocessing and POS-tagging

# %%
import gensim
from gensim.utils import simple_preprocess
from gensim.parsing.preprocessing import STOPWORDS
from nltk.stem import WordNetLemmatizer, SnowballStemmer
from nltk.stem.porter import *
from tqdm import tqdm
import nltk

# %%
tokens = []

for content in tqdm(corpus):
    t = gensim.utils.simple_preprocess(content)
    tokens.append(t)
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████████| 4/4 [00:00<00:00, 334.26it/s]

# %%
pos_tokens = []
pos_list = ['NN','NNS','NNP','NNPS']
for sublist in tqdm(tokens):
    temp = nltk.pos_tag(sublist)
    temp = [i for i in temp if i[1] in pos_list]
    pos_tokens.append(temp)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████| 4/4 [00:00<00:00, 21.11it/s]

# %%
pos_tokens
# Out:
# [[('effect', 'NN'),
#   ('reinforcement', 'NN'),
#   ('learning', 'NN'),
#   ('stock', 'NN'),
#   ('market', 'NN'),
#   ('product', 'NN'),
#   ('failure', 'NN'),
#   ('prediction', 'NN'),
#   ('data', 'NNS'),
#   ('stock', 'NN'),
#   ('price', 'NN'),
#   ('prediction', 'NN'),
#   ('sentiment', 'NN'),
#   ('analysis', 'NN'),
#   ('disclosures', 'NNS'),
#   ('representation', 'NN'),
#   ('convolution', 'NN'),
#   ('filter', 'NN'),
#   ('word', 'NN'),
#   ('clustering', 'NN'),
#   ('representation', 'NN'),
#   ('knowledge', 'NN'),
#   ('extraction', 'NN'),
#   ('visualization', 'NN'),
#   ('design', 'NN'),
#   ('process', 'NN'),
#   ('documents', 'NNS'),
#   ('detection', 'NN'),
#   ('method', 'NN'),
#   ('class', 'NN'),
#   ('vectors', 'NNS'),
#   ('customer', 'NN'),
#   ('voice', 'NN'),
#   ('classification', 'NN'),
#   ('smartphone', 'NN'),
#   ('user', 'NN'),
#   ('segmentation', 'NN'),
#   ('sequence', 'NN'),
#   ('networks', 'NNS'),
#   ('industry', 'NN'),
#   ('network', 'NN'),
#   ('business', 'NN'),
#   ('text', 'NN'),
#   ('disclosures', 'NNS'),
#   ('news', 'NN'),
#   ('machine', 'NN'),
#   ('detection', 'NN'),
#   ('integration', 'NN'),
#   ('inspection', 'NN'),
#   ('sales', 'NNS'),
#   ('service', 'NN'),
#   ('data', 'NNS'),
#   ('bag', 'NN'),
#   ('concepts', 'NNS'),
#   ('document', 'NN'),
#   ('representation', 'NN'),
#   ('words', 'NNS'),
#   ('representation', 'NN'),
#   ('prediction', 'NN'),
#   ('drug', 'NN'),
#   ('failure', 'NN'),
#   ('option', 'NN'),
#   ('relationship', 'NN'),
#   ('production', 'NN'),
#   ('customer', 'NN'),
#   ('service', 'NN'),
#   ('data', 'NNS'),
#   ('failure', 'NN'),
#   ('analysis', 'NN'),
#   ('products', 'NNS'),
#   ('metrology', 'NN'),
#   ('copper', 'NN'),
#   ('clad', 'NN'),
#   ('laminate', 'NN'),
#   ('manufacturing', 'NN'),
#   ('probability', 'NN'),
#   ('roc', 'NN'),
#   ('office', 'NN'),
#   ('forecasting', 'NN'),
#   ('sentiments', 'NNS'),
#   ('movie', 'NN'),
#   ('reviews', 'NNS'),
#   ('subspace', 'NN'),
#   ('method', 'NN'),
#   ('feature', 'NN'),
#   ('selection', 'NN'),
#   ('search', 'NN'),
#   ('metrology', 'NN'),
#   ('misstatements', 'NNS'),
#   ('fraud', 'NN'),
#   ('intention', 'NN'),
#   ('class', 'NN'),
#   ('cost', 'NN'),
#   ('semi', 'NN'),
#   ('support', 'NN'),
#   ('vector', 'NN'),
#   ('regression', 'NN'),
#   ('self', 'NNS'),
#   ('uncertainty', 'NN'),
#   ('application', 'NN'),
#   ('metrology', 'NN'),
#   ('semiconductor', 'NN'),
#   ('manufacturing', 'NN'),
#   ('energy', 'NN'),
#   ('decision', 'NN'),
#   ('making', 'NN'),
#   ('framework', 'NN'),
#   ('hvac', 'NN'),
#   ('logs', 'NNS'),
#   ('study', 'NN'),
#   ('man', 'NN'),
#   ('hour', 'NN'),
#   ('prediction', 'NN'),
#   ('system', 'NN'),
#   ('construction', 'NN'),
#   ('classifier', 'NN'),
#   ('meta', 'NN'),
#   ('wafer', 'NN'),
#   ('map', 'NN'),
#   ('features', 'NNS'),
#   ('predict', 'NN'),
#   ('level', 'NN'),
#   ('failures', 'NNS'),
#   ('test', 'NN'),
#   ('minority', 'NN'),
#   ('class', 'NN'),
#   ('proportion', 'NN'),
#   ('roc', 'NN'),
#   ('curve', 'NN'),
#   ('personality', 'NN'),
#   ('inventory', 'NN'),
#   ('data', 'NNS'),
#   ('rok', 'NN'),
#   ('forces', 'NNS'),
#   ('class', 'NN'),
#   ('classification', 'NN'),
#   ('ensemble', 'NN'),
#   ('class', 'NN'),
#   ('classifiers', 'NNS'),
#   ('class', 'NN'),
#   ('classification', 'NN'),
#   ('algorithm', 'NNS'),
#   ('class', 'NN'),
#   ('support', 'NN'),
#   ('vector', 'NN'),
#   ('machine', 'NN'),
#   ('dynamics', 'NNS'),
#   ('authentication', 'NN'),
#   ('text', 'NN'),
#   ('strings', 'NNS'),
#   ('input', 'NN'),
#   ('devices', 'NNS'),
#   ('efficient', 'NN'),
#   ('ensemble', 'NN'),
#   ('support', 'NN'),
#   ('vector', 'NN'),
#   ('machines', 'NNS'),
#   ('drug', 'NN'),
#   ('failure', 'NN'),
#   ('prediction', 'NN'),
#   ('memory', 'NN'),
#   ('die', 'NN'),
#   ('clustering', 'NN'),
#   ('voltage', 'NN'),
#   ('window', 'NN'),
#   ('semiconductor', 'NN'),
#   ('추천', 'NN'),
#   ('시스템', 'NNP'),
#   ('기법', 'NNP'),
#   ('연구동향', 'NNP'),
#   ('분석', 'NNP'),
#   ('set', 'NN'),
#   ('keywords', 'NNS'),
#   ('search', 'NN'),
#   ('engine', 'NN'),
#   ('advertising', 'NN'),
#   ('improvement', 'NN'),
#   ('metrology', 'NN'),
#   ('performance', 'NN'),
#   ('metrology', 'NN'),
#   ('noises', 'NNS'),
#   ('training', 'NN'),
#   ('dataset', 'NN'),
#   ('class', 'NN'),
#   ('classifier', 'NN'),
#   ('approach', 'NN'),
#   ('classifiers', 'NNS'),
#   ('word', 'NN'),
#   ('extraction', 'NN'),
#   ('method', 'NN'),
#   ('wordrank', 'NN'),
#   ('learning', 'NN'),
#   ('reliability', 'NN'),
#   ('level', 'NN'),
#   ('metrology', 'NN'),
#   ('results', 'NNS'),
#   ('process', 'NN'),
#   ('control', 'NN'),
#   ('novelty', 'NN'),
#   ('detection', 'NN'),
#   ('approach', 'NN'),
#   ('support', 'NN'),
#   ('vector', 'NN'),
#   ('machine', 'NN'),
#   ('network', 'NN'),
#   ('fast', 'NN'),
#   ('prediction', 'NN'),
#   ('reconstruction', 'NN'),
#   ('regression', 'NN'),
#   ('application', 'NN'),
#   ('metrology', 'NN'),
#   ('semiconductor', 'NN'),
#   ('manufacturing', 'NN'),
#   ('data', 'NNS'),
#   ('segmentation', 'NN'),
#   ('summarization', 'NN'),
#   ('sensor', 'NN'),
#   ('data', 'NNS'),
#   ('semiconductor', 'NN'),
#   ('manufacturing', 'NN'),
#   ('knowledge', 'NN'),
#   ('discovery', 'NN'),
#   ('inspection', 'NN'),
#   ('reports', 'NNS'),
#   ('structures', 'NNS'),
#   ('launch', 'NN'),
#   ('point', 'NN'),
#   ('estimation', 'NN'),
#   ('search', 'NN'),
#   ('multivariate', 'NN'),
#   ('control', 'NN'),
#   ('charts', 'NNS'),
#   ('novelty', 'NN'),
#   ('scores', 'NNS'),
#   ('design', 'NN'),
#   ('data', 'NNS'),
#   ('tenure', 'NN'),
#   ('diversity', 'NN'),
#   ('predictors', 'NNS'),
#   ('combat', 'NN'),
#   ('performance', 'NN'),
#   ('army', 'NN'),
#   ('mining', 'NN'),
#   ('transportation', 'NN'),
#   ('logs', 'NNS'),
#   ('assembly', 'NN'),
#   ('block', 'NN'),
#   ('manufacturing', 'NN'),
#   ('process', 'NN'),
#   ('shipbuilding', 'NN'),
#   ('industry', 'NN'),
#   ('pattern', 'NN'),
#   ('selection', 'NN'),
#   ('support', 'NN'),
#   ('vector', 'NN'),
#   ('regression', 'NN'),
#   ('response', 'NN'),
#   ('support', 'NN'),
#   ('vector', 'NN'),
#   ('class', 'NN'),
#   ('description', 'NN'),
#   ('svcd', 'NN'),
#   ('classification', 'NN'),
#   ('kernel', 'NN'),
#   ('space', 'NN'),
#   ('response', 'NN'),
#   ('machine', 'NN'),
#   ('novelty', 'NN'),
#   ('detection', 'NN'),
#   ('faulty', 'NN'),
#   ('wafer', 'NN'),
#   ('detection', 'NN'),
#   ('semiconductor', 'NN'),
#   ('manufacturing', 'NN'),
#   ('metrology', 'NN'),
#   ('run', 'NN'),
#   ('control', 'NN'),
#   ('semiconductor', 'NN'),
#   ('manufacturing', 'NN'),
#   ('semi', 'NN'),
#   ('response', 'NN'),
#   ('account', 'NN'),
#   ('detection', 'NN'),
#   ('keystroke', 'NN'),
#   ('dynamics', 'NNS'),
#   ('metrology', 'NN'),
#   ('system', 'NN'),
#   ('semiconductor', 'NN'),
#   ('manufacturing', 'NN'),
#   ('hybrid', 'NN'),
#   ('novelty', 'NN'),
#   ('score', 'NN'),
#   ('use', 'NN'),
#   ('keystroke', 'NN'),
#   ('dynamics', 'NNS'),
#   ('authentication', 'NN'),
#   ('authentication', 'NN'),
#   ('accuracy', 'NN'),
#   ('rhythms', 'NN'),
#   ('cues', 'NNS'),
#   ('keystroke', 'NN'),
#   ('dynamics', 'NNS'),
#   ('authentication', 'NN'),
#   ('dynamics', 'NNS'),
#   ('authentication', 'NN'),
#   ('devices', 'NNS'),
#   ('reconstruction', 'NN'),
#   ('instance', 'NN'),
#   ('improvement', 'NN'),
#   ('keystroke', 'NN'),
#   ('data', 'NNS'),
#   ('quality', 'NN'),
#   ('rhythms', 'NN'),
#   ('cues', 'NNS'),
#   ('selection', 'NN'),
#   ('support', 'NN'),
#   ('vector', 'NN'),
#   ('regression', 'NN'),
#   ('diagnosis', 'NN'),
#   ('attention', 'NN'),
#   ('deficit', 'NN'),
#   ('disorder', 'NN'),
#   ('detection', 'NN'),
#   ('response', 'NN'),
#   ('support', 'NN'),
#   ('vector', 'NN'),
#   ('regression', 'NN'),
#   ('reference', 'NN'),
#   ('reduction', 'NN'),
#   ('neighbor', 'NN'),
#   ('retraining', 'NN'),
#   ('keystroke', 'NN'),
#   ('dynamics', 'NNS'),
#   ('authenticator', 'NN'),
#   ('dynamics', 'NNS'),
#   ('authenticator', 'NN'),
#   ('impostor', 'NN'),
#   ('patterns', 'NNS'),
#   ('respondents', 'NNS'),
#   ('response', 'NN'),
#   ('novelty', 'NN'),
#   ('detectors', 'NNS'),
#   ('property', 'NN'),
#   ('selection', 'NN'),
#   ('support', 'NN'),
#   ('vector', 'NN'),
#   ('machines', 'NNS'),
#   ('novelty', 'NN'),
#   ('detection', 'NN'),
#   ('approach', 'NN'),
#   ('degrees', 'NNS'),
#   ('class', 'NN'),
#   ('imbalance', 'NN'),
#   ('eus', 'NN'),
#   ('svms', 'NN'),
#   ('ensemble', 'NN'),
#   ('svms', 'NN'),
#   ('data', 'NNS'),
#   ('imbalance', 'NN'),
#   ('problems', 'NNS'),
#   ('selection', 'NN'),
#   ('support', 'NN'),
#   ('vector', 'NN'),
#   ('machines', 'NNS'),
#   ('authentication', 'NN'),
#   ('accuracy', 'NN'),
#   ('passwords', 'NNS'),
#   ('pauses', 'NNS'),
#   ('cues', 'NNS'),
#   ('keystroke', 'NN'),
#   ('dynamics', 'NNS'),
#   ('authentication', 'NN'),
#   ('effectiveness', 'NN'),
#   ('rhythms', 'NN'),
#   ('cues', 'NNS'),
#   ('keystroke', 'NN'),
#   ('dynamics', 'NNS'),
#   ('authentication', 'NN'),
#   ('application', 'NN'),
#   ('lvq', 'NN'),
#   ('detection', 'NN'),
#   ('outliers', 'NNS'),
#   ('data', 'NNS'),
#   ('feature', 'NN'),
#   ('selection', 'NN'),
#   ('response', 'NN'),
#   ('vector', 'NN'),
#   ('machines', 'NNS'),
#   ('response', 'NN'),
#   ('model', 'NN'),
#   ('feature', 'NN'),
#   ('selection', 'NN'),
#   ('data', 'NNS'),
#   ('mining', 'NN'),
#   ('problems', 'NNS'),
#   ('solutions', 'NNS'),
#   ('response', 'NN'),
#   ('modeling', 'NN'),
#   ('crm', 'NN'),
#   ('ga', 'NN'),
#   ('svm', 'NN'),
#   ('ensemble', 'NN'),
#   ('keystroke', 'NN'),
#   ('dynamics', 'NNS'),
#   ('classification', 'NN'),
#   ('behavior', 'NN'),
#   ('attitude', 'NN'),
#   ('surface', 'NN'),
#   ('encephalogram', 'NN'),
#   ('line', 'NN'),
#   ('game', 'NN'),
#   ('novelty', 'NN'),
#   ('detector', 'NN'),
#   ('impostor', 'NN'),
#   ('patterns', 'NNS'),
#   ('keystroke', 'NN'),
#   ('dynamics', 'NNS'),
#   ('authentication', 'NN'),
#   ('rhythms', 'NN'),
#   ('cues', 'NNS'),
#   ('keystroke', 'NN'),
#   ('dynamics', 'NNS'),
#   ('authentication', 'NN'),
#   ('som', 'NN'),
#   ('novelty', 'NN'),
#   ('detection', 'NN'),
#   ('data', 'NNS'),
#   ('invariance', 'NN'),
#   ('neighborhood', 'NN'),
#   ('relation', 'NN'),
#   ('input', 'NN'),
#   ('space', 'NN'),
#   ('space', 'NN'),
#   ('response', 'NN'),
#   ('models', 'NNS'),
#   ('networks', 'NNS'),
#   ('mixture', 'NN'),
#   ('models', 'NNS'),
#   ('dynamics', 'NNS'),
#   ('identity', 'NN'),
#   ('verification', 'NN'),
#   ('problems', 'NNS'),
#   ('solutions', 'NNS'),
#   ('selection', 'NN'),
#   ('algorithm', 'NN'),
#   ('support', 'NN'),
#   ('vector', 'NN'),
#   ('classifiers', 'NNS'),
#   ('time', 'NN'),
#   ('complexity', 'NN'),
#   ('analysis', 'NN'),
#   ('novelty', 'NN'),
#   ('detection', 'NN'),
#   ('approach', 'NN'),
#   ('keystroke', 'NN'),
#   ('dynamics', 'NNS'),
#   ('identity', 'NN'),
#   ('verification', 'NN'),
#   ('selection', 'NN'),
#   ('support', 'NN'),
#   ('vector', 'NN'),
#   ('classifiers', 'NNS'),
#   ('rainfall', 'NN'),
#   ('runoff', 'NN'),
#   ('models', 'NNS'),
#   ('prediction', 'NN'),
#   ('rainfall', 'NN'),
#   ('runoff', 'NN'),
#   ('models', 'NNS'),
#   ('networks', 'NNS'),
#   ('trend', 'NN'),
#   ('detection', 'NN'),
#   ('auto', 'NN'),
#   ('network', 'NN'),
#   ('kospi', 'NN'),
#   ('futures', 'NNS'),
#   ('selection', 'NN'),
#   ('support', 'NN'),
#   ('vector', 'NN'),
#   ('classifiers', 'NNS'),
#   ('learning', 'NN'),
#   ('algorithm', 'NN'),
#   ('ensemble', 'NN'),
#   ('networks', 'NNS'),
#   ('kernel', 'NNS'),
#   ('selectors', 'NNS'),
#   ('networks', 'NNS'),
#   ('detection', 'NN'),
#   ('stock', 'NN'),
#   ('price', 'NN'),
#   ('index', 'NN'),
#   ('auto', 'NN'),
#   ('network', 'NN'),
#   ('web', 'NN'),
#   ('dynamics', 'NNS'),
#   ('identity', 'NN'),
#   ('verification', 'NN'),
#   ('network', 'NN'),
#   ('permeability', 'NN'),
#   ('predictions', 'NNS'),
#   ('learning', 'NN'),
#   ('algorithm', 'NN'),
#   ('networks', 'NNS'),
#   ('data', 'NNS'),
#   ('network', 'NN'),
#   ('method', 'NN'),
#   ('position', 'NN'),
#   ('monitors', 'NNS'),
#   ('storage', 'NN'),
#   ('ring', 'NN'),
#   ('speed', 'NN'),
#   ('control', 'NN'),
#   ('plant', 'NN'),
#   ('networks', 'NNS'),
#   ('interpolation', 'NN'),
#   ('network', 'NN'),
#   ('roll', 'NN'),
#   ('force', 'NN'),
#   ('prediction', 'NN'),
#   ('cold', 'NN'),
#   ('mill', 'NN'),
#   ('networks', 'NNS'),
#   ('sample', 'NN'),
#   ('generation', 'NN'),
#   ('population', 'NN'),
#   ('networks', 'NNS'),
#   ('rotation', 'NN'),
#   ('population', 'NN'),
#   ('vectors', 'NNS'),
#   ('rotation', 'NN'),
#   ('network', 'NN'),
#   ('prediction', 'NN'),
#   ('model', 'NN'),
#   ('cold', 'NN'),
#   ('mill', 'NN'),
#   ('design', 'NN'),
#   ('guidelines', 'NNS'),
#   ('character', 'NN'),
#   ('rejection', 'NN'),
#   ('substitution', 'NN'),
#   ('line', 'NN'),
#   ('document', 'NN'),
#   ('systems', 'NNS'),
#   ('effects', 'NNS'),
#   ('parameters', 'NNS'),
#   ('properties', 'NNS'),
#   ('self', 'NN'),
#   ('maps', 'NNS'),
#   ('formation', 'NN'),
#   ('cortex', 'NN'),
#   ('disorder', 'NN'),
#   ('diagnosis', 'NN'),
#   ('networks', 'NNS'),
#   ('competition', 'NN'),
#   ('cooperation', 'NN'),
#   ('improvement', 'NN'),
#   ('kittler', 'NN'),
#   ('error', 'NN')],
#  [('facility', 'NN'),
#   ('location', 'NN'),
#   ('model', 'NN'),
#   ('drones', 'NNS'),
#   ('flight', 'NN'),
#   ('distances', 'NNS'),
#   ('rebates', 'NNS'),
#   ('investigation', 'NN'),
#   ('price', 'NN'),
#   ('stock', 'NN'),
#   ('level', 'NN'),
#   ('rebate', 'NN'),
#   ('demand', 'NN'),
#   ('bat', 'NN'),
#   ('algorithm', 'NN'),
#   ('wartime', 'NN'),
#   ('logistics', 'NNS'),
#   ('model', 'NN'),
#   ('support', 'NN'),
#   ('unit', 'NN'),
#   ('location', 'NN'),
#   ('allocation', 'NN'),
#   ('problem', 'NN'),
#   ('line', 'NN'),
#   ('changes', 'NNS'),
#   ('pricing', 'NN'),
#   ('inventory', 'NN'),
#   ('decisions', 'NNS'),
#   ('carbon', 'NN'),
#   ('emission', 'NN'),
#   ('considerations', 'NNS'),
#   ('backordering', 'NN'),
#   ('discounts', 'NNS'),
#   ('investment', 'NN'),
#   ('coordination', 'NN'),
#   ('decisions', 'NNS'),
#   ('supply', 'NN'),
#   ('chain', 'NN'),
#   ('products', 'NNS'),
#   ('system', 'NN'),
#   ('operations', 'NNS'),
#   ('environment', 'NN'),
#   ('scheduling', 'NN'),
#   ('repair', 'NN'),
#   ('crew', 'NN'),
#   ('relief', 'NN'),
#   ('vehicle', 'NN'),
#   ('disaster', 'NN'),
#   ('ii', 'NN'),
#   ('algorithm', 'NN'),
#   ('production', 'NN'),
#   ('system', 'NN'),
#   ('product', 'NN'),
#   ('quality', 'NN'),
#   ('returns', 'NNS'),
#   ('warranty', 'NN'),
#   ('policies', 'NNS'),
#   ('salesman', 'NN'),
#   ('problem', 'NN'),
#   ('drone', 'NN'),
#   ('station', 'NN'),
#   ('network', 'NN'),
#   ('repair', 'NN'),
#   ('term', 'NN'),
#   ('disasters', 'NNS'),
#   ('relief', 'NN'),
#   ('shelter', 'NN'),
#   ('location', 'NN'),
#   ('problem', 'NN'),
#   ('severity', 'NN'),
#   ('relief', 'NN'),
#   ('budget', 'NN'),
#   ('range', 'NN'),
#   ('truck', 'NN'),
#   ('state', 'NN'),
#   ('transition', 'NN'),
#   ('method', 'NN'),
#   ('container', 'NN'),
#   ('drayage', 'NN'),
#   ('services', 'NNS'),
#   ('service', 'NN'),
#   ('routes', 'NNS'),
#   ('container', 'NN'),
#   ('management', 'NN'),
#   ('strategy', 'NN'),
#   ('model', 'NN'),
#   ('line', 'NN'),
#   ('workers', 'NNS'),
#   ('algorithm', 'NNS'),
#   ('case', 'NN'),
#   ('stage', 'NN'),
#   ('response', 'NN'),
#   ('problem', 'NN'),
#   ('post', 'NN'),
#   ('disaster', 'NN'),
#   ('incidents', 'NNS'),
#   ('product', 'NN'),
#   ('quality', 'NN'),
#   ('collection', 'NN'),
#   ('optimization', 'NN'),
#   ('loop', 'NN'),
#   ('supply', 'NN'),
#   ('chain', 'NN'),
#   ('channel', 'NNS'),
#   ('game', 'NN'),
#   ('approach', 'NN'),
#   ('impact', 'NN'),
#   ('sales', 'NNS'),
#   ('channel', 'NN'),
#   ('supply', 'NN'),
#   ('chains', 'NNS'),
#   ('inventory', 'NN'),
#   ('manufacturer', 'NN'),
#   ('vs', 'NN'),
#   ('retailer', 'NN'),
#   ('investment', 'NN'),
#   ('supply', 'NN'),
#   ('chain', 'NN'),
#   ('coordination', 'NN'),
#   ('supplier', 'NN'),
#   ('retailers', 'NNS'),
#   ('customer', 'NN'),
#   ('arrival', 'NN'),
#   ('times', 'NNS'),
#   ('selection', 'NN'),
#   ('joint', 'NN'),
#   ('decisions', 'NNS'),
#   ('product', 'NN'),
#   ('line', 'NN'),
#   ('selection', 'NN'),
#   ('purchasing', 'NN'),
#   ('pricing', 'NN'),
#   ('decisions', 'NNS'),
#   ('price', 'NN'),
#   ('quality', 'NN'),
#   ('effort', 'NN'),
#   ('level', 'NN'),
#   ('return', 'NN'),
#   ('policy', 'NN'),
#   ('level', 'NN'),
#   ('supply', 'NN'),
#   ('chain', 'NN'),
#   ('game', 'NN'),
#   ('theory', 'NN'),
#   ('approaches', 'NNS'),
#   ('capacity', 'NN'),
#   ('transshipment', 'NN'),
#   ('supply', 'NN'),
#   ('chain', 'NN'),
#   ('integer', 'NN'),
#   ('program', 'NN'),
#   ('algorithm', 'NN'),
#   ('university', 'NN'),
#   ('problem', 'NN'),
#   ('retailer', 'NN'),
#   ('investments', 'NNS'),
#   ('operations', 'NNS'),
#   ('preservation', 'NN'),
#   ('technology', 'NN'),
#   ('items', 'NNS'),
#   ('production', 'NN'),
#   ('distribution', 'NN'),
#   ('problem', 'NN'),
#   ('carbon', 'NN'),
#   ('emission', 'NN'),
#   ('constraint', 'NN'),
#   ('distribution', 'NN'),
#   ('newsboy', 'NN'),
#   ('problem', 'NN'),
#   ('discounts', 'NNS'),
#   ('upgrades', 'NNS'),
#   ('depot', 'NN'),
#   ('vehicle', 'NN'),
#   ('problem', 'NN'),
#   ('time', 'NN'),
#   ('windows', 'NNS'),
#   ('delivery', 'NN'),
#   ('installation', 'NN'),
#   ('vehicles', 'NNS'),
#   ('resource', 'NN'),
#   ('assignment', 'NN'),
#   ('workload', 'NN'),
#   ('production', 'NN'),
#   ('channel', 'NN'),
#   ('supply', 'NN'),
#   ('chain', 'NN'),
#   ('coordination', 'NN'),
#   ('reward', 'NN'),
#   ('policy', 'NN'),
#   ('repositioning', 'NN'),
#   ('containers', 'NNS'),
#   ('containers', 'NNS'),
#   ('chain', 'NN'),
#   ('coordination', 'NN'),
#   ('budget', 'NN'),
#   ('constraints', 'NNS'),
#   ('algorithms', 'NN'),
#   ('container', 'NN'),
#   ('problem', 'NN'),
#   ('channel', 'NN'),
#   ('coordination', 'NN'),
#   ('stage', 'NN'),
#   ('supply', 'NN'),
#   ('chains', 'NNS'),
#   ('revenue', 'NN'),
#   ('contracts', 'NNS'),
#   ('budget', 'NN'),
#   ('constraints', 'NNS'),
#   ('ship', 'NN'),
#   ('deployment', 'NN'),
#   ('network', 'NN'),
#   ('design', 'NN'),
#   ('problem', 'NN'),
#   ('manufacturing', 'NN'),
#   ('setup', 'NN'),
#   ('cost', 'NN'),
#   ('reduction', 'NN'),
#   ('quality', 'NN'),
#   ('improvement', 'NN'),
#   ('distribution', 'NN'),
#   ('review', 'NN'),
#   ('inventory', 'NN'),
#   ('model', 'NN'),
#   ('service', 'NN'),
#   ('level', 'NN'),
#   ('constraint', 'NN'),
#   ('productivity', 'NN'),
#   ('modular', 'NN'),
#   ('assembly', 'NN'),
#   ('study', 'NN'),
#   ('module', 'NN'),
#   ('suppliers', 'NNS'),
#   ('problem', 'NN'),
#   ('balance', 'NN'),
#   ('constraints', 'NNS'),
#   ('network', 'NN'),
#   ('flow', 'NN'),
#   ('model', 'NN'),
#   ('allocation', 'NN'),
#   ('containers', 'NNS'),
#   ('quality', 'NN'),
#   ('setup', 'NN'),
#   ('cost', 'NN'),
#   ('reduction', 'NN'),
#   ('backorder', 'NN'),
#   ('costs', 'NNS'),
#   ('production', 'NN'),
#   ('process', 'NN'),
#   ('hub', 'NN'),
#   ('logistics', 'NNS'),
#   ('network', 'NN'),
#   ('restrictions', 'NNS'),
#   ('case', 'NN'),
#   ('study', 'NN'),
#   ('korea', 'NNS'),
#   ('planning', 'NN'),
#   ('business', 'NN'),
#   ('process', 'NN'),
#   ('execution', 'NN'),
#   ('business', 'NN'),
#   ('process', 'NN'),
#   ('management', 'NN'),
#   ('environments', 'NNS'),
#   ('optimization', 'NN'),
#   ('energy', 'NN'),
#   ('wireless', 'NN'),
#   ('sensor', 'NN'),
#   ('networks', 'NNS'),
#   ('lot', 'NN'),
#   ('supply', 'NN'),
#   ('problem', 'NN'),
#   ('time', 'NN'),
#   ('lot', 'NN'),
#   ('sizes', 'NNS'),
#   ('algorithms', 'NN'),
#   ('test', 'NN'),
#   ('bed', 'NN'),
#   ('problems', 'NNS'),
#   ('distribution', 'NN'),
#   ('review', 'NN'),
#   ('model', 'NN'),
#   ('service', 'NN'),
#   ('level', 'NN'),
#   ('constraint', 'NN'),
#   ('lead', 'NN'),
#   ('time', 'NN'),
#   ('revenue', 'NN'),
#   ('contracts', 'NNS'),
#   ('stage', 'NN'),
#   ('supply', 'NN'),
#   ('chain', 'NN'),
#   ('reliability', 'NN'),
#   ('considerations', 'NNS'),
#   ('delivery', 'NN'),
#   ('service', 'NN'),
#   ('network', 'NN'),
#   ('design', 'NN'),
#   ('service', 'NN'),
#   ('centers', 'NNS'),
#   ('demands', 'NNS'),
#   ('express', 'NN'),
#   ('delivery', 'NN'),
#   ('services', 'NNS'),
#   ('decision', 'NN'),
#   ('model', 'NN'),
#   ('alliance', 'NN'),
#   ('network', 'NN'),
#   ('design', 'NN'),
#   ('express', 'NN'),
#   ('delivery', 'NN'),
#   ('services', 'NNS'),
#   ('approach', 'NN'),
#   ('inventory', 'NN'),
#   ('management', 'NN'),
#   ('supply', 'NN'),
#   ('chain', 'NN'),
#   ('networks', 'NNS'),
#   ('containers', 'NNS'),
#   ('container', 'NN'),
#   ('vehicle', 'NN'),
#   ('problem', 'NN'),
#   ('time', 'NN'),
#   ('windows', 'NNS'),
#   ('overtime', 'NN'),
#   ('vehicles', 'NNS'),
#   ('algorithm', 'NN'),
#   ('strategy', 'NN'),
#   ('bin', 'NN'),
#   ('problem', 'NN'),
#   ('particle', 'NN'),
#   ('swarm', 'NN'),
#   ('optimization', 'NN'),
#   ('algorithm', 'NN'),
#   ('optimization', 'NN'),
#   ('problems', 'NNS'),
#   ('job', 'NN'),
#   ('shop', 'NN'),
#   ('problems', 'NNS'),
#   ('constraints', 'NNS'),
#   ('systems', 'NNS'),
#   ('capacity', 'NN'),
#   ('storage', 'NN'),
#   ('capacity', 'NN'),
#   ('expansion', 'NN'),
#   ('space', 'NN'),
#   ('leasing', 'NN'),
#   ('container', 'NN'),
#   ('depots', 'NNS'),
#   ('optimization', 'NN'),
#   ('container', 'NN'),
#   ('drayage', 'NN'),
#   ('problem', 'NN'),
#   ('resource', 'NN'),
#   ('constraints', 'NNS'),
#   ('replenishment', 'NN'),
#   ('consolidation', 'NN'),
#   ('warehouse', 'NN'),
#   ('supply', 'NN'),
#   ('chain', 'NN'),
#   ('model', 'NN'),
#   ('inflation', 'NN'),
#   ('production', 'NN'),
#   ('system', 'NN'),
#   ('fractal', 'NN'),
#   ('supply', 'NN'),
#   ('chain', 'NN'),
#   ('management', 'NN'),
#   ('trust', 'NN'),
#   ('model', 'NN'),
#   ('industry', 'NN'),
#   ('containers', 'NNS'),
#   ('ports', 'NNS'),
#   ('leasing', 'NN'),
#   ('purchasing', 'NN'),
#   ('considerations', 'NNS'),
#   ('supply', 'NN'),
#   ('chain', 'NN'),
#   ('network', 'NN'),
#   ('design', 'NN'),
#   ('tabu', 'NN'),
#   ('search', 'NN'),
#   ('algorithm', 'NN'),
#   ('multi', 'NN'),
#   ('depot', 'NN'),
#   ('container', 'NN'),
#   ('truck', 'NN'),
#   ('transportation', 'NN'),
#   ('problem', 'NN'),
#   ('line', 'NN'),
#   ('resource', 'NN'),
#   ('restrictions', 'NNS'),
#   ('inventory', 'NN'),
#   ('cycles', 'NNS'),
#   ('integer', 'NN'),
#   ('programming', 'NN'),
#   ('algorithm', 'NN'),
#   ('replenishment', 'NN'),
#   ('delivery', 'NN'),
#   ('scheduling', 'NN'),
#   ('warehouse', 'NN'),
#   ('retailer', 'NN'),
#   ('system', 'NN'),
#   ('hierarchy', 'NN'),
#   ('process', 'NN'),
#   ('distribution', 'NN'),
#   ('network', 'NN'),
#   ('simulation', 'NN'),
#   ('maintenance', 'NN'),
#   ('support', 'NN'),
#   ('system', 'NN'),
#   ('systems', 'NNS'),
#   ('replenishment', 'NN'),
#   ('problem', 'NN'),
#   ('suppliers', 'NNS'),
#   ('quantity', 'NN'),
#   ('discounts', 'NNS'),
#   ('algorithms', 'NN'),
#   ('job', 'NN'),
#   ('shop', 'NN'),
#   ('problems', 'NNS'),
#   ('routings', 'NNS'),
#   ('algorithm', 'NN'),
#   ('group', 'NN'),
#   ('technology', 'NN'),
#   ('lot', 'NN'),
#   ('problem', 'NN'),
#   ('replenishment', 'NN'),
#   ('problem', 'NN'),
#   ('resource', 'NN'),
#   ('restriction', 'NN'),
#   ('inventory', 'NN'),
#   ('models', 'NNS'),
#   ('compensation', 'NN'),
#   ('policy', 'NN'),
#   ('level', 'NN'),
#   ('supply', 'NN'),
#   ('chain', 'NN'),
#   ('product', 'NN'),
#   ('inventory', 'NN'),
#   ('system', 'NN'),
#   ('constraint', 'NN'),
#   ('replenishment', 'NN'),
#   ('problem', 'NN'),
#   ('quantity', 'NN'),
#   ('discounts', 'NNS'),
#   ('demand', 'NN'),
#   ('review', 'NN'),
#   ('inventory', 'NN'),
#   ('model', 'NN'),
#   ('production', 'NN'),
#   ('rate', 'NN'),
#   ('manufacturer', 'NN'),
#   ('order', 'NN'),
#   ('quantity', 'NN'),
#   ('models', 'NNS'),
#   ('items', 'NNS'),
#   ('inflation', 'NN'),
#   ('time', 'NN'),
#   ('note', 'NN'),
#   ('lot', 'NN'),
#   ('problem', 'NN'),
#   ('capacity', 'NN'),
#   ('constraints', 'NNS'),
#   ('capacity', 'NN'),
#   ('cost', 'NN'),
#   ('scheduling', 'NN'),
#   ('lot', 'NN'),
#   ('sizes', 'NNS'),
#   ('lot', 'NN'),
#   ('sizes', 'NNS'),
#   ('production', 'NN'),
#   ('systems', 'NNS'),
#   ('lot', 'NN'),
#   ('problem', 'NN'),
#   ('production', 'NN'),
#   ('processes', 'NNS'),
#   ('setup', 'NN'),
#   ('times', 'NNS'),
#   ('algorithm', 'NN'),
#   ('lot', 'NN'),
#   ('problem', 'NN'),
#   ('book', 'NN'),
#   ('review', 'NN'),
#   ('inventory', 'NN'),
#   ('management', 'NN'),
#   ('production', 'NN'),
#   ('planning', 'NN'),
#   ('comment', 'NN'),
#   ('boss', 'NN'),
#   ('goswami', 'NN'),
#   ('chaudhuri', 'NN'),
#   ('eoq', 'NN'),
#   ('model', 'NN'),
#   ('items', 'NNS'),
#   ('time', 'NN'),
#   ('demand', 'NN'),
#   ('rate', 'NN'),
#   ('shortages', 'NNS'),
#   ('inflation', 'NN'),
#   ('time', 'NN'),
#   ('multi', 'NN'),
#   ('item', 'NN'),
#   ('period', 'NN'),
#   ('problem', 'NN'),
#   ('stock', 'NN'),
#   ('units', 'NNS'),
#   ('order', 'NN'),
#   ('quantity', 'NN'),
#   ('model', 'NN'),
#   ('stock', 'NN'),
#   ('units', 'NNS'),
#   ('value', 'NN'),
#   ('shortages', 'NNS'),
#   ('population', 'NN'),
#   ('items', 'NNS'),
#   ('restrictions', 'NNS'),
#   ('reorder', 'NN'),
#   ('effects', 'NNS'),
#   ('inflation', 'NN'),
#   ('time', 'NN'),
#   ('value', 'NN'),
#   ('money', 'NN'),
#   ('order', 'NN'),
#   ('quantity', 'NN'),
#   ('model', 'NN'),
#   ('product', 'NN'),
#   ('life', 'NN'),
#   ('cycle', 'NN'),
#   ('item', 'NN'),
#   ('newsvendor', 'NN'),
#   ('problem', 'NN'),
#   ('budget', 'NN'),
#   ('constraint', 'NN'),
#   ('ordering', 'NN'),
#   ('costs', 'NNS'),
#   ('cycle', 'NN'),
#   ('stock', 'NN'),
#   ('subject', 'NN'),
#   ('constraints', 'NNS'),
#   ('effect', 'NN'),
#   ('stabilization', 'NN'),
#   ('period', 'NN'),
#   ('lot', 'NN'),
#   ('problem', 'NN'),
#   ('note', 'NN'),
#   ('time', 'NN'),
#   ('assumptions', 'NNS'),
#   ('review', 'NN'),
#   ('inventory', 'NN'),
#   ('models', 'NNS'),
#   ('policies', 'NNS'),
#   ('inventory', 'NN'),
#   ('systems', 'NNS'),
#   ('cost', 'NN'),
#   ('analysis', 'NN'),
#   ('sales', 'NNS'),
#   ('distribution', 'NN'),
#   ('job', 'NN'),
#   ('control', 'NN'),
#   ('problem', 'NN'),
#   ('distribution', 'NN'),
#   ('procedures', 'NNS'),
#   ('make', 'NN'),
#   ('order', 'NN'),
#   ('mto', 'NNS'),
#   ('advance', 'NN'),
#   ('mia', 'NN'),
#   ('policies', 'NNS'),
#   ('system', 'NN'),
#   ('analysis', 'NN'),
#   ('product', 'NN'),
#   ('lot', 'NN'),
#   ('production', 'NN'),
#   ('motor', 'NN'),
#   ('factory', 'NN'),
#   ('case', 'NN'),
#   ('stockouts', 'NNS'),
#   ('items', 'NNS'),
#   ('facility', 'NN'),
#   ('investment', 'NN'),
#   ('setup', 'NN'),
#   ('time', 'NN'),
#   ('lot', 'NN'),
#   ('problem', 'NN'),
#   ('distribution', 'NN'),
#   ('newsboy', 'NN'),
#   ('problem', 'NN'),
#   ('fomula', 'NN'),
#   ('gradient', 'NN'),
#   ('series', 'NN'),
#   ('payment', 'NN'),
#   ('payment', 'NN'),
#   ('loan', 'NN'),
#   ('skips', 'NNS'),
#   ('distribution', 'NN'),
#   ('review', 'NN'),
#   ('inventory', 'NN'),
#   ('system', 'NN'),
#   ('service', 'NN'),
#   ('level', 'NN'),
#   ('constraint', 'NN'),
#   ('lot', 'NN'),
#   ('size', 'NN'),
#   ('models', 'NNS'),
#   ('investment', 'NN'),
#   ('costs', 'NNS'),
#   ('setup', 'NN'),
#   ('reduction', 'NN'),
#   ('quality', 'NN'),
#   ('improvement', 'NN'),
#   ('review', 'NN'),
#   ('extensions', 'NNS'),
#   ('distribution', 'NN'),
#   ('procedures', 'NNS'),
#   ('inventory', 'NN'),
#   ('models', 'NNS'),
#   ('control', 'NN'),
#   ('process', 'NN'),
#   ('trial', 'NN'),
#   ('order', 'NN'),
#   ('quantity', 'NN'),
#   ('model', 'NN'),
#   ('horizon', 'NN'),
#   ('note', 'NN'),
#   ('investments', 'NNS'),
#   ('inventory', 'NN'),
#   ('system', 'NN'),
#   ('value', 'NN'),
#   ('framework', 'NN'),
#   ('note', 'NN'),
#   ('correction', 'NN'),
#   ('product', 'NN'),
#   ('machine', 'NN'),
#   ('distribution', 'NN'),
#   ('newsboy', 'NN'),
#   ('problem', 'NN'),
#   ('review', 'NN'),
#   ('extensions', 'NNS'),
#   ('impact', 'NN'),
#   ('quality', 'NN'),
#   ('improvement', 'NN'),
#   ('lot', 'NN'),
#   ('size', 'NN'),
#   ('model', 'NN'),
#   ('effect', 'NN'),
#   ('setups', 'NNS'),
#   ('lot', 'NN'),
#   ('problem', 'NN'),
#   ('production', 'NN'),
#   ('rates', 'NNS'),
#   ('family', 'NN'),
#   ('production', 'NN'),
#   ('context', 'NN')],
#  [('game', 'NN'),
#   ('model', 'NN'),
#   ('optimization', 'NN'),
#   ('agents', 'NNS'),
#   ('heterogenity', 'NN'),
#   ('precision', 'NN'),
#   ('pump', 'NN'),
#   ('schedule', 'NN'),
#   ('optimization', 'NN'),
#   ('water', 'NN'),
#   ('supply', 'NN'),
#   ('networks', 'NNS'),
#   ('buffers', 'NNS'),
#   ('polynomiality', 'NN'),
#   ('programming', 'NN'),
#   ('time', 'NN'),
#   ('algorithms', 'NN'),
#   ('optimization', 'NN'),
#   ('constraints', 'NNS'),
#   ('complexity', 'NN'),
#   ('production', 'NN'),
#   ('transportation', 'NN'),
#   ('problem', 'NN'),
#   ('multicast', 'NN'),
#   ('algorithm', 'NN'),
#   ('delay', 'NN'),
#   ('applications', 'NNS'),
#   ('membership', 'NN'),
#   ('online', 'NN'),
#   ('algorithm', 'NN'),
#   ('paging', 'NN'),
#   ('problem', 'NN'),
#   ('shelf', 'NN'),
#   ('memory', 'NN'),
#   ('time', 'NN'),
#   ('vp', 'NN'),
#   ('management', 'NN'),
#   ('nets', 'NNS'),
#   ('algorithms', 'NN'),
#   ('multicast', 'NN'),
#   ('trees', 'NNS'),
#   ('replication', 'NN'),
#   ('restrictions', 'NNS'),
#   ('topology', 'NN'),
#   ('configuration', 'NN'),
#   ('multicast', 'NN'),
#   ('atm', 'NN'),
#   ('mpls', 'NN'),
#   ('networks', 'NNS'),
#   ('bicriteria', 'NN'),
#   ('approximation', 'NN'),
#   ('scheme', 'NN'),
#   ('spanning', 'NN'),
#   ('tree', 'NN'),
#   ('problem', 'NN'),
#   ('connection', 'NN'),
#   ('level', 'NN'),
#   ('qos', 'NN'),
#   ('transmission', 'NN'),
#   ('technology', 'NN'),
#   ('system', 'NN'),
#   ('server', 'NN'),
#   ('network', 'NN'),
#   ('disconnection', 'NN'),
#   ('problem', 'NN'),
#   ('approximability', 'NN'),
#   ('server', 'NN'),
#   ('disconnection', 'NN'),
#   ('problem', 'NN'),
#   ('polynomiality', 'NN'),
#   ('sparsest', 'NN'),
#   ('cuts', 'NNS'),
#   ('number', 'NN'),
#   ('sources', 'NNS'),
#   ('algorithm', 'NN'),
#   ('replenishment', 'NN'),
#   ('inventory', 'NN'),
#   ('cost', 'NN'),
#   ('pseudo', 'NN'),
#   ('heuristic', 'NN'),
#   ('path', 'NN'),
#   ('time', 'NN'),
#   ('target', 'NN'),
#   ('search', 'NN'),
#   ('unification', 'NN'),
#   ('bound', 'NN'),
#   ('analyses', 'NNS'),
#   ('lift', 'NN'),
#   ('project', 'NN'),
#   ('rank', 'NN'),
#   ('optimization', 'NN'),
#   ('polyhedra', 'NN'),
#   ('algorithm', 'NN'),
#   ('train', 'NN'),
#   ('set', 'NN'),
#   ('case', 'NN'),
#   ('korea', 'NN'),
#   ('speed', 'NN'),
#   ('railway', 'NN'),
#   ('search', 'NN'),
#   ('relocation', 'NN'),
#   ('trade', 'NN'),
#   ('target', 'NN'),
#   ('approximation', 'NN'),
#   ('batch', 'NN'),
#   ('consolidation', 'NN'),
#   ('problem', 'NN'),
#   ('approximation', 'NN'),
#   ('batch', 'NN'),
#   ('consolidation', 'NN'),
#   ('problem', 'NN'),
#   ('appraisal', 'NN'),
#   ('column', 'NN'),
#   ('generation', 'NN'),
#   ('algorithm', 'NN'),
#   ('train', 'NN'),
#   ('conflict', 'NN'),
#   ('resolution', 'NN'),
#   ('railway', 'NN'),
#   ('network', 'NN'),
#   ('rank', 'NN'),
#   ('handelman', 'NN'),
#   ('hierarchy', 'NN'),
#   ('max', 'NN'),
#   ('cut', 'NN'),
#   ('rank', 'NN'),
#   ('programs', 'NNS'),
#   ('hypercube', 'NN'),
#   ('applications', 'NNS'),
#   ('column', 'NN'),
#   ('generation', 'NN'),
#   ('approach', 'NN'),
#   ('line', 'NN'),
#   ('patterns', 'NNS'),
#   ('application', 'NN'),
#   ('speed', 'NN'),
#   ('railway', 'NN'),
#   ('optimization', 'NN'),
#   ('future', 'NN'),
#   ('soldier', 'NN'),
#   ('system', 'NN'),
#   ('approach', 'NN'),
#   ('agent', 'NN'),
#   ('simulation', 'NN'),
#   ('response', 'NN'),
#   ('surface', 'NN'),
#   ('method', 'NN'),
#   ('path', 'NN'),
#   ('choice', 'NN'),
#   ('metro', 'NN'),
#   ('passengers', 'NNS'),
#   ('train', 'NN'),
#   ('logs', 'NNS'),
#   ('card', 'NN'),
#   ('data', 'NNS'),
#   ('estimation', 'NN'),
#   ('connections', 'NNS'),
#   ('passengers', 'NNS'),
#   ('card', 'NN'),
#   ('data', 'NNS'),
#   ('express', 'NN'),
#   ('train', 'NN'),
#   ('choice', 'NN'),
#   ('passenger', 'NN'),
#   ('card', 'NN'),
#   ('data', 'NNS'),
#   ('method', 'NN'),
#   ('taste', 'NN'),
#   ('heterogeneity', 'NN'),
#   ('travellers', 'NNS'),
#   ('choice', 'NN'),
#   ('transport', 'NN'),
#   ('routes', 'NNS')],
#  [('case', 'NN'),
#   ('approach', 'NN'),
#   ('optimization', 'NN'),
#   ('travel', 'NN'),
#   ('routes', 'NNS'),
#   ('scale', 'NN'),
#   ('rss', 'NN'),
#   ('operations', 'NNS'),
#   ('delay', 'NN'),
#   ('re', 'NN'),
#   ('chip', 'NN'),
#   ('product', 'NN'),
#   ('assembly', 'NN'),
#   ('lines', 'NNS'),
#   ('inattention', 'NN'),
#   ('detection', 'NN'),
#   ('method', 'NN'),
#   ('signal', 'NN'),
#   ('laplace', 'NN'),
#   ('inference', 'NN'),
#   ('equation', 'NN'),
#   ('models', 'NNS'),
#   ('device', 'NN'),
#   ('gender', 'NN'),
#   ('prediction', 'NN'),
#   ('method', 'NN'),
#   ('users', 'NNS'),
#   ('wordsets', 'NNS'),
#   ('scheduling', 'NN'),
#   ('semiconductor', 'NN'),
#   ('manufacturing', 'NN'),
#   ('facilities', 'NNS'),
#   ('case', 'NN'),
#   ('place', 'NN'),
#   ('prediction', 'NN'),
#   ('pattern', 'NN'),
#   ('mining', 'NN'),
#   ('device', 'NN'),
#   ('logs', 'NNS'),
#   ('design', 'NN'),
#   ('strategies', 'NNS'),
#   ('screens', 'NNS'),
#   ('smartphones', 'NNS'),
#   ('service', 'NN'),
#   ('usages', 'NNS'),
#   ('manufacturing', 'NN'),
#   ('schedule', 'NN'),
#   ('feature', 'NN'),
#   ('utilization', 'NN'),
#   ('approach', 'NN'),
#   ('retrieval', 'NN'),
#   ('online', 'NN'),
#   ('shopping', 'NN'),
#   ('services', 'NNS'),
#   ('extraction', 'NN'),
#   ('topics', 'NNS'),
#   ('text', 'NN'),
#   ('setup', 'NN'),
#   ('change', 'NN'),
#   ('semiconductor', 'NN'),
#   ('packaging', 'NN'),
#   ('facilities', 'NNS'),
#   ('algorithm', 'NN'),
#   ('operator', 'NN'),
#   ('recommender', 'NN'),
#   ('mobile', 'NN'),
#   ('phone', 'NN'),
#   ('purchase', 'NN'),
#   ('behaviors', 'NNS'),
#   ('adopter', 'NN'),
#   ('groups', 'NNS'),
#   ('hypovigilance', 'NN'),
#   ('detection', 'NN'),
#   ('ucav', 'NN'),
#   ('operators', 'NNS'),
#   ('markov', 'NN'),
#   ('model', 'NN'),
#   ('return', 'NN'),
#   ('investment', 'NN'),
#   ('assessment', 'NN'),
#   ('model', 'NN'),
#   ('interface', 'NN'),
#   ('project', 'NN'),
#   ('predevelopment', 'NN'),
#   ('stage', 'NN'),
#   ('composition', 'NN'),
#   ('pattern', 'NN'),
#   ('extraction', 'NN'),
#   ('documents', 'NNS'),
#   ('language', 'NN'),
#   ('kernels', 'NNS'),
#   ('text', 'NN'),
#   ('classification', 'NN'),
#   ('feature', 'NN'),
#   ('identification', 'NN'),
#   ('relevance', 'NN'),
#   ('assessment', 'NN'),
#   ('feed', 'NN'),
#   ('search', 'NN'),
#   ('engines', 'NNS'),
#   ('fraud', 'NN'),
#   ('detection', 'NN'),
#   ('shopping', 'NN'),
#   ('malls', 'NNS'),
#   ('mixture', 'NN'),
#   ('model', 'NN'),
#   ('topic', 'NN'),
#   ('photo', 'NN'),
#   ('retrieval', 'NN'),
#   ('revenue', 'NN'),
#   ('construction', 'NN'),
#   ('online', 'NN'),
#   ('shopping', 'NN'),
#   ('services', 'NNS'),
#   ('resource', 'NN'),
#   ('allocation', 'NN'),
#   ('policy', 'NN'),
#   ('delay', 'NN'),
#   ('minimization', 'NN'),
#   ('feeds', 'NNS'),
#   ('optimization', 'NN'),
#   ('index', 'NN'),
#   ('freshness', 'NN'),
#   ('coverage', 'NN'),
#   ('time', 'NN'),
#   ('search', 'NN'),
#   ('engines', 'NNS'),
#   ('discovery', 'NN'),
#   ('information', 'NN'),
#   ('diffusion', 'NN'),
#   ('process', 'NN'),
#   ('networks', 'NNS'),
#   ('video', 'NN'),
#   ('recommendation', 'NN'),
#   ('aggregation', 'NN'),
#   ('flowwiki', 'NN'),
#   ('wiki', 'NN'),
#   ('platform', 'NN'),
#   ('ad', 'NN'),
#   ('hoc', 'NN'),
#   ('workflows', 'NNS'),
#   ('media', 'NNS'),
#   ('streams', 'NNS'),
#   ('web', 'NN'),
#   ('vector', 'NN'),
#   ('space', 'NN'),
#   ('approach', 'NN'),
#   ('similarity', 'NN'),
#   ('relationship', 'NN'),
#   ('keywords', 'NNS'),
#   ('feed', 'NN'),
#   ('elements', 'NNS'),
#   ('blog', 'NN'),
#   ('post', 'NN'),
#   ('search', 'NN'),
#   ('business', 'NN'),
#   ('performance', 'NN'),
#   ('measurement', 'NN'),
#   ('model', 'NN'),
#   ('interface', 'NN'),
#   ('work', 'NN'),
#   ('management', 'NN'),
#   ('workflows', 'NNS'),
#   ('eca', 'NN'),
#   ('framework', 'NN'),
#   ('coordination', 'NN'),
#   ('web', 'NN'),
#   ('services', 'NNS'),
#   ('approach', 'NN'),
#   ('stock', 'NN'),
#   ('trading', 'NN'),
#   ('approach', 'NN'),
#   ('business', 'NN'),
#   ('performance', 'NN'),
#   ('monitoring', 'NN'),
#   ('analysis', 'NN'),
#   ('time', 'NN'),
#   ('incorporation', 'NN'),
#   ('preferences', 'NNS'),
#   ('service', 'NN'),
#   ('conversations', 'NNS'),
#   ('coordination', 'NN'),
#   ('framework', 'NN'),
#   ('multi', 'NN'),
#   ('business', 'NN'),
#   ('transactions', 'NNS'),
#   ('web', 'NN'),
#   ('services', 'NNS'),
#   ('performance', 'NN'),
#   ('backoff', 'NN'),
#   ('protocol', 'NN'),
#   ('execution', 'NN'),
#   ('web', 'NN'),
#   ('services', 'NNS'),
#   ('communication', 'NN'),
#   ('supports', 'NNS'),
#   ('building', 'NN'),
#   ('world', 'NN'),
#   ('game', 'NN'),
#   ('communities', 'NNS'),
#   ('event', 'NN'),
#   ('peer', 'NN'),
#   ('process', 'NN'),
#   ('enactment', 'NN'),
#   ('web', 'NN'),
#   ('service', 'NN'),
#   ('devices', 'NNS'),
#   ('extraction', 'NN'),
#   ('conversation', 'NN'),
#   ('protocols', 'NNS'),
#   ('choreography', 'NN'),
#   ('specification', 'NN'),
#   ('web', 'NN'),
#   ('services', 'NNS'),
#   ('xslt', 'NN'),
#   ('framework', 'NN'),
#   ('peer', 'NN'),
#   ('interactions', 'NNS'),
#   ('business', 'NN'),
#   ('processes', 'NNS'),
#   ('deadlock', 'NN'),
#   ('livelock', 'NN'),
#   ('protocol', 'NN'),
#   ('internet', 'NN'),
#   ('resource', 'NN'),
#   ('coallocation', 'NN'),
#   ('protocol', 'NN'),
#   ('allocation', 'NN'),
#   ('web', 'NN'),
#   ('services', 'NNS'),
#   ('policy', 'NN'),
#   ('mixtures', 'NNS'),
#   ('approach', 'NN'),
#   ('flexibility', 'NN'),
#   ('resource', 'NN'),
#   ('allocation', 'NN'),
#   ('systems', 'NNS'),
#   ('routings', 'NNS'),
#   ('supervision', 'NN'),
#   ('resource', 'NN'),
#   ('allocation', 'NN'),
#   ('systems', 'NNS'),
#   ('behavior', 'NN'),
#   ('states', 'NNS'),
#   ('event', 'NN'),
#   ('control', 'NN'),
#   ('architecture', 'NN'),
#   ('systems', 'NNS'),
#   ('deadlock', 'NN'),
#   ('avoidance', 'NN'),
#   ('resource', 'NN'),
#   ('allocation', 'NN'),
#   ('systems', 'NNS'),
#   ('resource', 'NN'),
#   ('acquisitions', 'NNS'),
#   ('routings', 'NNS'),
#   ('fidelity', 'NN'),
#   ('prototyping', 'NN'),
#   ('mm', 'NN'),
#   ('fabs', 'NNS'),
#   ('event', 'NN'),
#   ('systems', 'NNS'),
#   ('correction', 'NN'),
#   ('run', 'NN'),
#   ('dap', 'NN'),
#   ('ras', 'NNS'),
#   ('complexity', 'NN'),
#   ('deadlock', 'NN'),
#   ('avoidance', 'NN'),
#   ('policies', 'NNS'),
#   ('resource', 'NN'),
#   ('allocation', 'NN'),
#   ('systems', 'NNS'),
#   ('synthesis', 'NN'),
#   ('deadlock', 'NN'),
#   ('avoidance', 'NN'),
#   ('policies', 'NNS'),
#   ('resource', 'NN'),
#   ('allocation', 'NN'),
#   ('systems', 'NNS'),
#   ('event', 'NN'),
#   ('control', 'NN'),
#   ('framework', 'NN'),
#   ('systems', 'NNS'),
#   ('voice', 'NN'),
#   ('conversion', 'NN'),
#   ('intonation', 'NN'),
#   ('auto', 'NN'),
#   ('encoder', 'NN'),
#   ('word', 'NN'),
#   ('rnn', 'NN'),
#   ('baseline', 'NN'),
#   ('sentence', 'NN'),
#   ('completion', 'NN'),
#   ('training', 'NN'),
#   ('level', 'NN'),
#   ('networks', 'NNS'),
#   ('speaker', 'NN'),
#   ('identification', 'NN'),
#   ('verification', 'NN'),
#   ('sequence', 'NN'),
#   ('model', 'NN'),
#   ('greedy', 'NN'),
#   ('grapheme', 'NN'),
#   ('conversion', 'NN'),
#   ('text', 'NN'),
#   ('gender', 'NN'),
#   ('classification', 'NN'),
#   ('approach', 'NN'),
#   ('reinforcement', 'NN'),
#   ('factory', 'NN'),
#   ('operation', 'NN'),
#   ('inference', 'NN'),
#   ('smartphone', 'NN'),
#   ('sensor', 'NN'),
#   ('data', 'NNS'),
#   ('model', 'NN'),
#   ('classification', 'NN'),
#   ('users', 'NNS'),
#   ('sensor', 'NN'),
#   ('semi', 'NN'),
#   ('inattention', 'NN'),
#   ('prediction', 'NN'),
#   ('framework', 'NN'),
#   ('vehicles', 'NNS'),
#   ('distance', 'NN'),
#   ('approach', 'NN'),
#   ('places', 'NNS'),
#   ('trajectory', 'NN'),
#   ('data', 'NNS'),
#   ('schedule', 'NN'),
#   ('phase', 'NN'),
#   ('method', 'NN'),
#   ('tire', 'NN'),
#   ('production', 'NN'),
#   ('planning', 'NN'),
#   ('problem', 'NN'),
#   ('instant', 'NN'),
#   ('planning', 'NN'),
#   ('case', 'NN'),
#   ('semi', 'NN'),
#   ('method', 'NN'),
#   ('inattention', 'NN'),
#   ('prediction', 'NN'),
#   ('machine', 'NN'),
#   ('interaction', 'NN'),
#   ('systems', 'NNS'),
#   ('prediction', 'NN'),
#   ('role', 'NN'),
#   ('playing', 'NN'),
#   ('game', 'NN'),
#   ('markov', 'NN'),
#   ('model', 'NN'),
#   ('feature', 'NN'),
#   ('item', 'NN'),
#   ('approach', 'NN'),
#   ('construction', 'NN'),
#   ('price', 'NN'),
#   ('comparison', 'NN'),
#   ('shopping', 'NN'),
#   ('services', 'NNS'),
#   ('class', 'NN'),
#   ('text', 'NN'),
#   ('classification', 'NN'),
#   ('performance', 'NN'),
#   ('support', 'NN'),
#   ('vector', 'NN'),
#   ('machine', 'NN'),
#   ('classifiers', 'NNS'),
#   ('event', 'NN'),
#   ('detection', 'NN'),
#   ('streams', 'NNS'),
#   ('disaster', 'NN'),
#   ('management', 'NN'),
#   ('pattern', 'NN'),
#   ('tree', 'NN'),
#   ('kernels', 'NNS'),
#   ('text', 'NN'),
#   ('classification', 'NN'),
#   ('model', 'NN'),
#   ('sequence', 'NN'),
#   ('data', 'NNS'),
#   ('classification', 'NN'),
#   ('svm', 'NN'),
#   ('keyword', 'NN'),
#   ('extraction', 'NN'),
#   ('microblogs', 'NNS'),
#   ('time', 'NN'),
#   ('search', 'NN'),
#   ('engine', 'NN'),
#   ('retrieval', 'NN'),
#   ('media', 'NNS'),
#   ('time', 'NN'),
#   ('challenges', 'NNS'),
#   ('search', 'NN'),
#   ('text', 'NN'),
#   ('mining', 'NN'),
#   ('retrieval', 'NN'),
#   ('models', 'NNS'),
#   ('information', 'NN'),
#   ('discovery', 'NN'),
#   ('time', 'NN'),
#   ('svm', 'NN'),
#   ('approach', 'NN'),
#   ('selection', 'NN'),
#   ('relevance', 'NN'),
#   ('judgement', 'NN'),
#   ('feeds', 'NNS'),
#   ('time', 'NN'),
#   ('road', 'NN'),
#   ('function', 'NN'),
#   ('sets', 'NNS'),
#   ('topic', 'NN'),
#   ('coverage', 'NN'),
#   ('tag', 'NN'),
#   ('similarity', 'NN'),
#   ('computation', 'NN'),
#   ('term', 'NN'),
#   ('space', 'NN'),
#   ('dimension', 'NN'),
#   ('reduction', 'NN'),
#   ('study', 'NN'),
#   ('measurements', 'NNS'),
#   ('model', 'NN'),
#   ('business', 'NN'),
#   ('performance', 'NN'),
#   ('interface', 'NN'),
#   ('business', 'NN'),
#   ('technology', 'NN'),
#   ('roadmap', 'NN'),
#   ('field', 'NN'),
#   ('study', 'NN'),
#   ('icon', 'NN'),
#   ('communication', 'NN'),
#   ('interactions', 'NNS'),
#   ('incorporation', 'NN'),
#   ('preferences', 'NNS'),
#   ('service', 'NN'),
#   ('conversations', 'NNS'),
#   ('approach', 'NN'),
#   ('business', 'NN'),
#   ('performance', 'NN'),
#   ('monitoring', 'NN'),
#   ('analysis', 'NN'),
#   ('time', 'NN'),
#   ('communication', 'NN'),
#   ('supports', 'NNS'),
#   ('building', 'NN'),
#   ('world', 'NN'),
#   ('game', 'NN'),
#   ('communities', 'NNS'),
#   ('event', 'NN'),
#   ('peer', 'NN'),
#   ('process', 'NN'),
#   ('enactment', 'NN'),
#   ('web', 'NN'),
#   ('service', 'NN'),
#   ('devices', 'NNS'),
#   ('preference', 'NN'),
#   ('profile', 'NN'),
#   ('web', 'NN'),
#   ('services', 'NNS'),
#   ('conversation', 'NN'),
#   ('environment', 'NN'),
#   ('extraction', 'NN'),
#   ('conversation', 'NN'),
#   ('protocols', 'NNS'),
#   ('choreography', 'NN'),
#   ('specification', 'NN'),
#   ('web', 'NN'),
#   ('services', 'NNS'),
#   ('eca', 'NN'),
#   ('rule', 'NN'),
#   ('description', 'NN'),
#   ('language', 'NN'),
#   ('services', 'NNS'),
#   ('event', 'NN'),
#   ('coordination', 'NN'),
#   ('rule', 'NN'),
#   ('web', 'NN'),
#   ('services', 'NNS'),
#   ('devices', 'NNS'),
#   ('environments', 'NNS'),
#   ('conversation', 'NN'),
#   ('preference', 'NN'),
#   ('profile', 'NN'),
#   ('web', 'NN'),
#   ('service', 'NN'),
#   ('xpia', 'NNP'),
#   ('bpms', 'NN'),
#   ('framework', 'NN'),
#   ('process', 'NN'),
#   ('improvement', 'NN'),
#   ('business', 'NN'),
#   ('processes', 'NNS'),
#   ('generation', 'NN'),
#   ('conversation', 'NN'),
#   ('protocols', 'NNS'),
#   ('preferences', 'NNS'),
#   ('service', 'NN'),
#   ('conversations', 'NNS'),
#   ('web', 'NN'),
#   ('service', 'NN'),
#   ('transaction', 'NN'),
#   ('protocol', 'NN'),
#   ('pc', 'NN'),
#   ('thp', 'NN'),
#   ('ws', 'NN'),
#   ('cpp', 'NN'),
#   ('web', 'NN'),
#   ('services', 'NNS'),
#   ('conversation', 'NN'),
#   ('preference', 'NN'),
#   ('profile', 'NN'),
#   ('approach', 'NN'),
#   ('stock', 'NN'),
#   ('trading', 'NN'),
#   ('agents', 'NNS'),
#   ('performance', 'NN'),
#   ('protocol', 'NN'),
#   ('execution', 'NN'),
#   ('web', 'NN'),
#   ('services', 'NNS'),
#   ('advances', 'NNS'),
#   ('web', 'NN'),
#   ('services', 'NNS'),
#   ('composition', 'NN'),
#   ('implications', 'NNS'),
#   ('business', 'NN'),
#   ('process', 'NN'),
#   ('integration', 'NN'),
#   ('composition', 'NN'),
#   ('co', 'NN'),
#   ('business', 'NN'),
#   ('xslt', 'NN'),
#   ('framework', 'NN'),
#   ('peer', 'NN'),
#   ('interactions', 'NNS'),
#   ('business', 'NN'),
#   ('design', 'NN'),
#   ('hold', 'NN'),
#   ('protocol', 'NN'),
#   ('coordination', 'NN'),
#   ('multi', 'NN'),
#   ('business', 'NN'),
#   ('transactions', 'NNS'),
#   ('allocation', 'NN'),
#   ('web', 'NN'),
#   ('services', 'NNS'),
#   ('protocol', 'NN'),
#   ('deadlock', 'NN'),
#   ('livelock', 'NN'),
#   ('co', 'NN'),
#   ('allocation', 'NN'),
#   ('resources', 'NNS'),
#   ('internet', 'NN'),
#   ('supervision', 'NN'),
#   ('resource', 'NN'),
#   ('allocation', 'NN'),
#   ('systems', 'NNS'),
#   ('states', 'NNS'),
#   ('events', 'NNS'),
#   ('fidelity', 'NN'),
#   ('simulator', 'NN'),
#   ('mm', 'NN'),
#   ('wafer', 'NN'),
#   ('fabs', 'NN'),
#   ('algebraic', 'NN'),
#   ('deadlock', 'NN'),
#   ('avoidance', 'NN'),
#   ('policies', 'NNS'),
#   ('resource', 'NN'),
#   ('allocation', 'NN'),
#   ('systems', 'NNS'),
#   ('net', 'NN'),
#   ('approach', 'NN'),
#   ('design', 'NN'),
#   ('mm', 'NN'),
#   ('wafer', 'NN'),
#   ('fab', 'NN'),
#   ('controllers', 'NNS'),
#   ('complexity', 'NN'),
#   ('deadlock', 'NN'),
#   ('avoidance', 'NN'),
#   ('policy', 'NN'),
#   ('resource', 'NN'),
#   ('allocation', 'NN'),
#   ('systems', 'NNS'),
#   ('resource', 'NN'),
#   ('acquisitions', 'NNS'),
#   ('routings', 'NNS'),
#   ('fidelity', 'NN'),
#   ('prototyping', 'NN'),
#   ('time', 'NN'),
#   ('operations', 'NNS'),
#   ('event', 'NN'),
#   ('system', 'NN'),
#   ('specification', 'NN'),
#   ('approach', 'NN'),
#   ('software', 'NN'),
#   ('control', 'NN'),
#   ('fidelity', 'NN'),
#   ('factory', 'NN'),
#   ('flexibility', 'NN'),
#   ('deadlock', 'NN'),
#   ('avoidance', 'NN'),
#   ('policies', 'NNS'),
#   ('analysis', 'NN'),
#   ('petri', 'NN'),
#   ('net', 'NN'),
#   ('design', 'NN'),
#   ('deadlock', 'NN'),
#   ('avoidance', 'NN'),
#   ('policies', 'NNS'),
#   ('resource', 'NN'),
#   ('allocation', 'NN'),
#   ('systems', 'NNS'),
#   ('integration', 'NN'),
#   ('performance', 'NN'),
#   ('control', 'NN'),
#   ('manufacturing', 'NN'),
#   ('analysis', 'NN'),
#   ('deadlock', 'NN'),
#   ('avoidance', 'NN'),
#   ('unit', 'NN'),
#   ('resource', 'NN'),
#   ('allocation', 'NN'),
#   ('systems', 'NNS'),
#   ('event', 'NN'),
#   ('control', 'NN'),
#   ('approach', 'NN'),
#   ('cell', 'NN'),
#   ('system', 'NN'),
#   ('design', 'NN'),
#   ('control', 'NN'),
#   ('systems', 'NNS'),
#   ('agent', 'NN'),
#   ('architecture', 'NN'),
#   ('strategies', 'NNS'),
#   ('coordination', 'NN'),
#   ('environment', 'NN'),
#   ('development', 'NN'),
#   ('application', 'NN'),
#   ('builder', 'NN'),
#   ('object', 'NN'),
#   ('framework', 'NN'),
#   ('object', 'NN'),
#   ('time', 'NN'),
#   ('executive', 'NN'),
#   ('control', 'NN'),
#   ('manufacturing', 'NN'),
#   ('systems', 'NNS')]]

# %%
final_tokens = []
lem = WordNetLemmatizer()
for sublist in pos_tokens:
    temp=[]
    for item in sublist:
        t = lem.lemmatize(item[0], pos='n')
        temp.append(t)
    final_tokens.append(temp)

# %%
final_tokens
# Out:
# [['effect',
#   'reinforcement',
#   'learning',
#   'stock',
#   'market',
#   'product',
#   'failure',
#   'prediction',
#   'data',
#   'stock',
#   'price',
#   'prediction',
#   'sentiment',
#   'analysis',
#   'disclosure',
#   'representation',
#   'convolution',
#   'filter',
#   'word',
#   'clustering',
#   'representation',
#   'knowledge',
#   'extraction',
#   'visualization',
#   'design',
#   'process',
#   'document',
#   'detection',
#   'method',
#   'class',
#   'vector',
#   'customer',
#   'voice',
#   'classification',
#   'smartphone',
#   'user',
#   'segmentation',
#   'sequence',
#   'network',
#   'industry',
#   'network',
#   'business',
#   'text',
#   'disclosure',
#   'news',
#   'machine',
#   'detection',
#   'integration',
#   'inspection',
#   'sale',
#   'service',
#   'data',
#   'bag',
#   'concept',
#   'document',
#   'representation',
#   'word',
#   'representation',
#   'prediction',
#   'drug',
#   'failure',
#   'option',
#   'relationship',
#   'production',
#   'customer',
#   'service',
#   'data',
#   'failure',
#   'analysis',
#   'product',
#   'metrology',
#   'copper',
#   'clad',
#   'laminate',
#   'manufacturing',
#   'probability',
#   'roc',
#   'office',
#   'forecasting',
#   'sentiment',
#   'movie',
#   'review',
#   'subspace',
#   'method',
#   'feature',
#   'selection',
#   'search',
#   'metrology',
#   'misstatement',
#   'fraud',
#   'intention',
#   'class',
#   'cost',
#   'semi',
#   'support',
#   'vector',
#   'regression',
#   'self',
#   'uncertainty',
#   'application',
#   'metrology',
#   'semiconductor',
#   'manufacturing',
#   'energy',
#   'decision',
#   'making',
#   'framework',
#   'hvac',
#   'log',
#   'study',
#   'man',
#   'hour',
#   'prediction',
#   'system',
#   'construction',
#   'classifier',
#   'meta',
#   'wafer',
#   'map',
#   'feature',
#   'predict',
#   'level',
#   'failure',
#   'test',
#   'minority',
#   'class',
#   'proportion',
#   'roc',
#   'curve',
#   'personality',
#   'inventory',
#   'data',
#   'rok',
#   'force',
#   'class',
#   'classification',
#   'ensemble',
#   'class',
#   'classifier',
#   'class',
#   'classification',
#   'algorithm',
#   'class',
#   'support',
#   'vector',
#   'machine',
#   'dynamic',
#   'authentication',
#   'text',
#   'string',
#   'input',
#   'device',
#   'efficient',
#   'ensemble',
#   'support',
#   'vector',
#   'machine',
#   'drug',
#   'failure',
#   'prediction',
#   'memory',
#   'die',
#   'clustering',
#   'voltage',
#   'window',
#   'semiconductor',
#   '추천',
#   '시스템',
#   '기법',
#   '연구동향',
#   '분석',
#   'set',
#   'keywords',
#   'search',
#   'engine',
#   'advertising',
#   'improvement',
#   'metrology',
#   'performance',
#   'metrology',
#   'noise',
#   'training',
#   'dataset',
#   'class',
#   'classifier',
#   'approach',
#   'classifier',
#   'word',
#   'extraction',
#   'method',
#   'wordrank',
#   'learning',
#   'reliability',
#   'level',
#   'metrology',
#   'result',
#   'process',
#   'control',
#   'novelty',
#   'detection',
#   'approach',
#   'support',
#   'vector',
#   'machine',
#   'network',
#   'fast',
#   'prediction',
#   'reconstruction',
#   'regression',
#   'application',
#   'metrology',
#   'semiconductor',
#   'manufacturing',
#   'data',
#   'segmentation',
#   'summarization',
#   'sensor',
#   'data',
#   'semiconductor',
#   'manufacturing',
#   'knowledge',
#   'discovery',
#   'inspection',
#   'report',
#   'structure',
#   'launch',
#   'point',
#   'estimation',
#   'search',
#   'multivariate',
#   'control',
#   'chart',
#   'novelty',
#   'score',
#   'design',
#   'data',
#   'tenure',
#   'diversity',
#   'predictor',
#   'combat',
#   'performance',
#   'army',
#   'mining',
#   'transportation',
#   'log',
#   'assembly',
#   'block',
#   'manufacturing',
#   'process',
#   'shipbuilding',
#   'industry',
#   'pattern',
#   'selection',
#   'support',
#   'vector',
#   'regression',
#   'response',
#   'support',
#   'vector',
#   'class',
#   'description',
#   'svcd',
#   'classification',
#   'kernel',
#   'space',
#   'response',
#   'machine',
#   'novelty',
#   'detection',
#   'faulty',
#   'wafer',
#   'detection',
#   'semiconductor',
#   'manufacturing',
#   'metrology',
#   'run',
#   'control',
#   'semiconductor',
#   'manufacturing',
#   'semi',
#   'response',
#   'account',
#   'detection',
#   'keystroke',
#   'dynamic',
#   'metrology',
#   'system',
#   'semiconductor',
#   'manufacturing',
#   'hybrid',
#   'novelty',
#   'score',
#   'use',
#   'keystroke',
#   'dynamic',
#   'authentication',
#   'authentication',
#   'accuracy',
#   'rhythm',
#   'cue',
#   'keystroke',
#   'dynamic',
#   'authentication',
#   'dynamic',
#   'authentication',
#   'device',
#   'reconstruction',
#   'instance',
#   'improvement',
#   'keystroke',
#   'data',
#   'quality',
#   'rhythm',
#   'cue',
#   'selection',
#   'support',
#   'vector',
#   'regression',
#   'diagnosis',
#   'attention',
#   'deficit',
#   'disorder',
#   'detection',
#   'response',
#   'support',
#   'vector',
#   'regression',
#   'reference',
#   'reduction',
#   'neighbor',
#   'retraining',
#   'keystroke',
#   'dynamic',
#   'authenticator',
#   'dynamic',
#   'authenticator',
#   'impostor',
#   'pattern',
#   'respondent',
#   'response',
#   'novelty',
#   'detector',
#   'property',
#   'selection',
#   'support',
#   'vector',
#   'machine',
#   'novelty',
#   'detection',
#   'approach',
#   'degree',
#   'class',
#   'imbalance',
#   'eu',
#   'svms',
#   'ensemble',
#   'svms',
#   'data',
#   'imbalance',
#   'problem',
#   'selection',
#   'support',
#   'vector',
#   'machine',
#   'authentication',
#   'accuracy',
#   'password',
#   'pause',
#   'cue',
#   'keystroke',
#   'dynamic',
#   'authentication',
#   'effectiveness',
#   'rhythm',
#   'cue',
#   'keystroke',
#   'dynamic',
#   'authentication',
#   'application',
#   'lvq',
#   'detection',
#   'outlier',
#   'data',
#   'feature',
#   'selection',
#   'response',
#   'vector',
#   'machine',
#   'response',
#   'model',
#   'feature',
#   'selection',
#   'data',
#   'mining',
#   'problem',
#   'solution',
#   'response',
#   'modeling',
#   'crm',
#   'ga',
#   'svm',
#   'ensemble',
#   'keystroke',
#   'dynamic',
#   'classification',
#   'behavior',
#   'attitude',
#   'surface',
#   'encephalogram',
#   'line',
#   'game',
#   'novelty',
#   'detector',
#   'impostor',
#   'pattern',
#   'keystroke',
#   'dynamic',
#   'authentication',
#   'rhythm',
#   'cue',
#   'keystroke',
#   'dynamic',
#   'authentication',
#   'som',
#   'novelty',
#   'detection',
#   'data',
#   'invariance',
#   'neighborhood',
#   'relation',
#   'input',
#   'space',
#   'space',
#   'response',
#   'model',
#   'network',
#   'mixture',
#   'model',
#   'dynamic',
#   'identity',
#   'verification',
#   'problem',
#   'solution',
#   'selection',
#   'algorithm',
#   'support',
#   'vector',
#   'classifier',
#   'time',
#   'complexity',
#   'analysis',
#   'novelty',
#   'detection',
#   'approach',
#   'keystroke',
#   'dynamic',
#   'identity',
#   'verification',
#   'selection',
#   'support',
#   'vector',
#   'classifier',
#   'rainfall',
#   'runoff',
#   'model',
#   'prediction',
#   'rainfall',
#   'runoff',
#   'model',
#   'network',
#   'trend',
#   'detection',
#   'auto',
#   'network',
#   'kospi',
#   'future',
#   'selection',
#   'support',
#   'vector',
#   'classifier',
#   'learning',
#   'algorithm',
#   'ensemble',
#   'network',
#   'kernel',
#   'selector',
#   'network',
#   'detection',
#   'stock',
#   'price',
#   'index',
#   'auto',
#   'network',
#   'web',
#   'dynamic',
#   'identity',
#   'verification',
#   'network',
#   'permeability',
#   'prediction',
#   'learning',
#   'algorithm',
#   'network',
#   'data',
#   'network',
#   'method',
#   'position',
#   'monitor',
#   'storage',
#   'ring',
#   'speed',
#   'control',
#   'plant',
#   'network',
#   'interpolation',
#   'network',
#   'roll',
#   'force',
#   'prediction',
#   'cold',
#   'mill',
#   'network',
#   'sample',
#   'generation',
#   'population',
#   'network',
#   'rotation',
#   'population',
#   'vector',
#   'rotation',
#   'network',
#   'prediction',
#   'model',
#   'cold',
#   'mill',
#   'design',
#   'guideline',
#   'character',
#   'rejection',
#   'substitution',
#   'line',
#   'document',
#   'system',
#   'effect',
#   'parameter',
#   'property',
#   'self',
#   'map',
#   'formation',
#   'cortex',
#   'disorder',
#   'diagnosis',
#   'network',
#   'competition',
#   'cooperation',
#   'improvement',
#   'kittler',
#   'error'],
#  ['facility',
#   'location',
#   'model',
#   'drone',
#   'flight',
#   'distance',
#   'rebate',
#   'investigation',
#   'price',
#   'stock',
#   'level',
#   'rebate',
#   'demand',
#   'bat',
#   'algorithm',
#   'wartime',
#   'logistics',
#   'model',
#   'support',
#   'unit',
#   'location',
#   'allocation',
#   'problem',
#   'line',
#   'change',
#   'pricing',
#   'inventory',
#   'decision',
#   'carbon',
#   'emission',
#   'consideration',
#   'backordering',
#   'discount',
#   'investment',
#   'coordination',
#   'decision',
#   'supply',
#   'chain',
#   'product',
#   'system',
#   'operation',
#   'environment',
#   'scheduling',
#   'repair',
#   'crew',
#   'relief',
#   'vehicle',
#   'disaster',
#   'ii',
#   'algorithm',
#   'production',
#   'system',
#   'product',
#   'quality',
#   'return',
#   'warranty',
#   'policy',
#   'salesman',
#   'problem',
#   'drone',
#   'station',
#   'network',
#   'repair',
#   'term',
#   'disaster',
#   'relief',
#   'shelter',
#   'location',
#   'problem',
#   'severity',
#   'relief',
#   'budget',
#   'range',
#   'truck',
#   'state',
#   'transition',
#   'method',
#   'container',
#   'drayage',
#   'service',
#   'service',
#   'route',
#   'container',
#   'management',
#   'strategy',
#   'model',
#   'line',
#   'worker',
#   'algorithm',
#   'case',
#   'stage',
#   'response',
#   'problem',
#   'post',
#   'disaster',
#   'incident',
#   'product',
#   'quality',
#   'collection',
#   'optimization',
#   'loop',
#   'supply',
#   'chain',
#   'channel',
#   'game',
#   'approach',
#   'impact',
#   'sale',
#   'channel',
#   'supply',
#   'chain',
#   'inventory',
#   'manufacturer',
#   'v',
#   'retailer',
#   'investment',
#   'supply',
#   'chain',
#   'coordination',
#   'supplier',
#   'retailer',
#   'customer',
#   'arrival',
#   'time',
#   'selection',
#   'joint',
#   'decision',
#   'product',
#   'line',
#   'selection',
#   'purchasing',
#   'pricing',
#   'decision',
#   'price',
#   'quality',
#   'effort',
#   'level',
#   'return',
#   'policy',
#   'level',
#   'supply',
#   'chain',
#   'game',
#   'theory',
#   'approach',
#   'capacity',
#   'transshipment',
#   'supply',
#   'chain',
#   'integer',
#   'program',
#   'algorithm',
#   'university',
#   'problem',
#   'retailer',
#   'investment',
#   'operation',
#   'preservation',
#   'technology',
#   'item',
#   'production',
#   'distribution',
#   'problem',
#   'carbon',
#   'emission',
#   'constraint',
#   'distribution',
#   'newsboy',
#   'problem',
#   'discount',
#   'upgrade',
#   'depot',
#   'vehicle',
#   'problem',
#   'time',
#   'window',
#   'delivery',
#   'installation',
#   'vehicle',
#   'resource',
#   'assignment',
#   'workload',
#   'production',
#   'channel',
#   'supply',
#   'chain',
#   'coordination',
#   'reward',
#   'policy',
#   'repositioning',
#   'container',
#   'container',
#   'chain',
#   'coordination',
#   'budget',
#   'constraint',
#   'algorithm',
#   'container',
#   'problem',
#   'channel',
#   'coordination',
#   'stage',
#   'supply',
#   'chain',
#   'revenue',
#   'contract',
#   'budget',
#   'constraint',
#   'ship',
#   'deployment',
#   'network',
#   'design',
#   'problem',
#   'manufacturing',
#   'setup',
#   'cost',
#   'reduction',
#   'quality',
#   'improvement',
#   'distribution',
#   'review',
#   'inventory',
#   'model',
#   'service',
#   'level',
#   'constraint',
#   'productivity',
#   'modular',
#   'assembly',
#   'study',
#   'module',
#   'supplier',
#   'problem',
#   'balance',
#   'constraint',
#   'network',
#   'flow',
#   'model',
#   'allocation',
#   'container',
#   'quality',
#   'setup',
#   'cost',
#   'reduction',
#   'backorder',
#   'cost',
#   'production',
#   'process',
#   'hub',
#   'logistics',
#   'network',
#   'restriction',
#   'case',
#   'study',
#   'korea',
#   'planning',
#   'business',
#   'process',
#   'execution',
#   'business',
#   'process',
#   'management',
#   'environment',
#   'optimization',
#   'energy',
#   'wireless',
#   'sensor',
#   'network',
#   'lot',
#   'supply',
#   'problem',
#   'time',
#   'lot',
#   'size',
#   'algorithm',
#   'test',
#   'bed',
#   'problem',
#   'distribution',
#   'review',
#   'model',
#   'service',
#   'level',
#   'constraint',
#   'lead',
#   'time',
#   'revenue',
#   'contract',
#   'stage',
#   'supply',
#   'chain',
#   'reliability',
#   'consideration',
#   'delivery',
#   'service',
#   'network',
#   'design',
#   'service',
#   'center',
#   'demand',
#   'express',
#   'delivery',
#   'service',
#   'decision',
#   'model',
#   'alliance',
#   'network',
#   'design',
#   'express',
#   'delivery',
#   'service',
#   'approach',
#   'inventory',
#   'management',
#   'supply',
#   'chain',
#   'network',
#   'container',
#   'container',
#   'vehicle',
#   'problem',
#   'time',
#   'window',
#   'overtime',
#   'vehicle',
#   'algorithm',
#   'strategy',
#   'bin',
#   'problem',
#   'particle',
#   'swarm',
#   'optimization',
#   'algorithm',
#   'optimization',
#   'problem',
#   'job',
#   'shop',
#   'problem',
#   'constraint',
#   'system',
#   'capacity',
#   'storage',
#   'capacity',
#   'expansion',
#   'space',
#   'leasing',
#   'container',
#   'depot',
#   'optimization',
#   'container',
#   'drayage',
#   'problem',
#   'resource',
#   'constraint',
#   'replenishment',
#   'consolidation',
#   'warehouse',
#   'supply',
#   'chain',
#   'model',
#   'inflation',
#   'production',
#   'system',
#   'fractal',
#   'supply',
#   'chain',
#   'management',
#   'trust',
#   'model',
#   'industry',
#   'container',
#   'port',
#   'leasing',
#   'purchasing',
#   'consideration',
#   'supply',
#   'chain',
#   'network',
#   'design',
#   'tabu',
#   'search',
#   'algorithm',
#   'multi',
#   'depot',
#   'container',
#   'truck',
#   'transportation',
#   'problem',
#   'line',
#   'resource',
#   'restriction',
#   'inventory',
#   'cycle',
#   'integer',
#   'programming',
#   'algorithm',
#   'replenishment',
#   'delivery',
#   'scheduling',
#   'warehouse',
#   'retailer',
#   'system',
#   'hierarchy',
#   'process',
#   'distribution',
#   'network',
#   'simulation',
#   'maintenance',
#   'support',
#   'system',
#   'system',
#   'replenishment',
#   'problem',
#   'supplier',
#   'quantity',
#   'discount',
#   'algorithm',
#   'job',
#   'shop',
#   'problem',
#   'routings',
#   'algorithm',
#   'group',
#   'technology',
#   'lot',
#   'problem',
#   'replenishment',
#   'problem',
#   'resource',
#   'restriction',
#   'inventory',
#   'model',
#   'compensation',
#   'policy',
#   'level',
#   'supply',
#   'chain',
#   'product',
#   'inventory',
#   'system',
#   'constraint',
#   'replenishment',
#   'problem',
#   'quantity',
#   'discount',
#   'demand',
#   'review',
#   'inventory',
#   'model',
#   'production',
#   'rate',
#   'manufacturer',
#   'order',
#   'quantity',
#   'model',
#   'item',
#   'inflation',
#   'time',
#   'note',
#   'lot',
#   'problem',
#   'capacity',
#   'constraint',
#   'capacity',
#   'cost',
#   'scheduling',
#   'lot',
#   'size',
#   'lot',
#   'size',
#   'production',
#   'system',
#   'lot',
#   'problem',
#   'production',
#   'process',
#   'setup',
#   'time',
#   'algorithm',
#   'lot',
#   'problem',
#   'book',
#   'review',
#   'inventory',
#   'management',
#   'production',
#   'planning',
#   'comment',
#   'bos',
#   'goswami',
#   'chaudhuri',
#   'eoq',
#   'model',
#   'item',
#   'time',
#   'demand',
#   'rate',
#   'shortage',
#   'inflation',
#   'time',
#   'multi',
#   'item',
#   'period',
#   'problem',
#   'stock',
#   'unit',
#   'order',
#   'quantity',
#   'model',
#   'stock',
#   'unit',
#   'value',
#   'shortage',
#   'population',
#   'item',
#   'restriction',
#   'reorder',
#   'effect',
#   'inflation',
#   'time',
#   'value',
#   'money',
#   'order',
#   'quantity',
#   'model',
#   'product',
#   'life',
#   'cycle',
#   'item',
#   'newsvendor',
#   'problem',
#   'budget',
#   'constraint',
#   'ordering',
#   'cost',
#   'cycle',
#   'stock',
#   'subject',
#   'constraint',
#   'effect',
#   'stabilization',
#   'period',
#   'lot',
#   'problem',
#   'note',
#   'time',
#   'assumption',
#   'review',
#   'inventory',
#   'model',
#   'policy',
#   'inventory',
#   'system',
#   'cost',
#   'analysis',
#   'sale',
#   'distribution',
#   'job',
#   'control',
#   'problem',
#   'distribution',
#   'procedure',
#   'make',
#   'order',
#   'mto',
#   'advance',
#   'mia',
#   'policy',
#   'system',
#   'analysis',
#   'product',
#   'lot',
#   'production',
#   'motor',
#   'factory',
#   'case',
#   'stockouts',
#   'item',
#   'facility',
#   'investment',
#   'setup',
#   'time',
#   'lot',
#   'problem',
#   'distribution',
#   'newsboy',
#   'problem',
#   'fomula',
#   'gradient',
#   'series',
#   'payment',
#   'payment',
#   'loan',
#   'skip',
#   'distribution',
#   'review',
#   'inventory',
#   'system',
#   'service',
#   'level',
#   'constraint',
#   'lot',
#   'size',
#   'model',
#   'investment',
#   'cost',
#   'setup',
#   'reduction',
#   'quality',
#   'improvement',
#   'review',
#   'extension',
#   'distribution',
#   'procedure',
#   'inventory',
#   'model',
#   'control',
#   'process',
#   'trial',
#   'order',
#   'quantity',
#   'model',
#   'horizon',
#   'note',
#   'investment',
#   'inventory',
#   'system',
#   'value',
#   'framework',
#   'note',
#   'correction',
#   'product',
#   'machine',
#   'distribution',
#   'newsboy',
#   'problem',
#   'review',
#   'extension',
#   'impact',
#   'quality',
#   'improvement',
#   'lot',
#   'size',
#   'model',
#   'effect',
#   'setup',
#   'lot',
#   'problem',
#   'production',
#   'rate',
#   'family',
#   'production',
#   'context'],
#  ['game',
#   'model',
#   'optimization',
#   'agent',
#   'heterogenity',
#   'precision',
#   'pump',
#   'schedule',
#   'optimization',
#   'water',
#   'supply',
#   'network',
#   'buffer',
#   'polynomiality',
#   'programming',
#   'time',
#   'algorithm',
#   'optimization',
#   'constraint',
#   'complexity',
#   'production',
#   'transportation',
#   'problem',
#   'multicast',
#   'algorithm',
#   'delay',
#   'application',
#   'membership',
#   'online',
#   'algorithm',
#   'paging',
#   'problem',
#   'shelf',
#   'memory',
#   'time',
#   'vp',
#   'management',
#   'net',
#   'algorithm',
#   'multicast',
#   'tree',
#   'replication',
#   'restriction',
#   'topology',
#   'configuration',
#   'multicast',
#   'atm',
#   'mpls',
#   'network',
#   'bicriteria',
#   'approximation',
#   'scheme',
#   'spanning',
#   'tree',
#   'problem',
#   'connection',
#   'level',
#   'qos',
#   'transmission',
#   'technology',
#   'system',
#   'server',
#   'network',
#   'disconnection',
#   'problem',
#   'approximability',
#   'server',
#   'disconnection',
#   'problem',
#   'polynomiality',
#   'sparsest',
#   'cut',
#   'number',
#   'source',
#   'algorithm',
#   'replenishment',
#   'inventory',
#   'cost',
#   'pseudo',
#   'heuristic',
#   'path',
#   'time',
#   'target',
#   'search',
#   'unification',
#   'bound',
#   'analysis',
#   'lift',
#   'project',
#   'rank',
#   'optimization',
#   'polyhedron',
#   'algorithm',
#   'train',
#   'set',
#   'case',
#   'korea',
#   'speed',
#   'railway',
#   'search',
#   'relocation',
#   'trade',
#   'target',
#   'approximation',
#   'batch',
#   'consolidation',
#   'problem',
#   'approximation',
#   'batch',
#   'consolidation',
#   'problem',
#   'appraisal',
#   'column',
#   'generation',
#   'algorithm',
#   'train',
#   'conflict',
#   'resolution',
#   'railway',
#   'network',
#   'rank',
#   'handelman',
#   'hierarchy',
#   'max',
#   'cut',
#   'rank',
#   'program',
#   'hypercube',
#   'application',
#   'column',
#   'generation',
#   'approach',
#   'line',
#   'pattern',
#   'application',
#   'speed',
#   'railway',
#   'optimization',
#   'future',
#   'soldier',
#   'system',
#   'approach',
#   'agent',
#   'simulation',
#   'response',
#   'surface',
#   'method',
#   'path',
#   'choice',
#   'metro',
#   'passenger',
#   'train',
#   'log',
#   'card',
#   'data',
#   'estimation',
#   'connection',
#   'passenger',
#   'card',
#   'data',
#   'express',
#   'train',
#   'choice',
#   'passenger',
#   'card',
#   'data',
#   'method',
#   'taste',
#   'heterogeneity',
#   'traveller',
#   'choice',
#   'transport',
#   'route'],
#  ['case',
#   'approach',
#   'optimization',
#   'travel',
#   'route',
#   'scale',
#   'r',
#   'operation',
#   'delay',
#   're',
#   'chip',
#   'product',
#   'assembly',
#   'line',
#   'inattention',
#   'detection',
#   'method',
#   'signal',
#   'laplace',
#   'inference',
#   'equation',
#   'model',
#   'device',
#   'gender',
#   'prediction',
#   'method',
#   'user',
#   'wordsets',
#   'scheduling',
#   'semiconductor',
#   'manufacturing',
#   'facility',
#   'case',
#   'place',
#   'prediction',
#   'pattern',
#   'mining',
#   'device',
#   'log',
#   'design',
#   'strategy',
#   'screen',
#   'smartphones',
#   'service',
#   'usage',
#   'manufacturing',
#   'schedule',
#   'feature',
#   'utilization',
#   'approach',
#   'retrieval',
#   'online',
#   'shopping',
#   'service',
#   'extraction',
#   'topic',
#   'text',
#   'setup',
#   'change',
#   'semiconductor',
#   'packaging',
#   'facility',
#   'algorithm',
#   'operator',
#   'recommender',
#   'mobile',
#   'phone',
#   'purchase',
#   'behavior',
#   'adopter',
#   'group',
#   'hypovigilance',
#   'detection',
#   'ucav',
#   'operator',
#   'markov',
#   'model',
#   'return',
#   'investment',
#   'assessment',
#   'model',
#   'interface',
#   'project',
#   'predevelopment',
#   'stage',
#   'composition',
#   'pattern',
#   'extraction',
#   'document',
#   'language',
#   'kernel',
#   'text',
#   'classification',
#   'feature',
#   'identification',
#   'relevance',
#   'assessment',
#   'feed',
#   'search',
#   'engine',
#   'fraud',
#   'detection',
#   'shopping',
#   'mall',
#   'mixture',
#   'model',
#   'topic',
#   'photo',
#   'retrieval',
#   'revenue',
#   'construction',
#   'online',
#   'shopping',
#   'service',
#   'resource',
#   'allocation',
#   'policy',
#   'delay',
#   'minimization',
#   'feed',
#   'optimization',
#   'index',
#   'freshness',
#   'coverage',
#   'time',
#   'search',
#   'engine',
#   'discovery',
#   'information',
#   'diffusion',
#   'process',
#   'network',
#   'video',
#   'recommendation',
#   'aggregation',
#   'flowwiki',
#   'wiki',
#   'platform',
#   'ad',
#   'hoc',
#   'workflow',
#   'medium',
#   'stream',
#   'web',
#   'vector',
#   'space',
#   'approach',
#   'similarity',
#   'relationship',
#   'keywords',
#   'feed',
#   'element',
#   'blog',
#   'post',
#   'search',
#   'business',
#   'performance',
#   'measurement',
#   'model',
#   'interface',
#   'work',
#   'management',
#   'workflow',
#   'eca',
#   'framework',
#   'coordination',
#   'web',
#   'service',
#   'approach',
#   'stock',
#   'trading',
#   'approach',
#   'business',
#   'performance',
#   'monitoring',
#   'analysis',
#   'time',
#   'incorporation',
#   'preference',
#   'service',
#   'conversation',
#   'coordination',
#   'framework',
#   'multi',
#   'business',
#   'transaction',
#   'web',
#   'service',
#   'performance',
#   'backoff',
#   'protocol',
#   'execution',
#   'web',
#   'service',
#   'communication',
#   'support',
#   'building',
#   'world',
#   'game',
#   'community',
#   'event',
#   'peer',
#   'process',
#   'enactment',
#   'web',
#   'service',
#   'device',
#   'extraction',
#   'conversation',
#   'protocol',
#   'choreography',
#   'specification',
#   'web',
#   'service',
#   'xslt',
#   'framework',
#   'peer',
#   'interaction',
#   'business',
#   'process',
#   'deadlock',
#   'livelock',
#   'protocol',
#   'internet',
#   'resource',
#   'coallocation',
#   'protocol',
#   'allocation',
#   'web',
#   'service',
#   'policy',
#   'mixture',
#   'approach',
#   'flexibility',
#   'resource',
#   'allocation',
#   'system',
#   'routings',
#   'supervision',
#   'resource',
#   'allocation',
#   'system',
#   'behavior',
#   'state',
#   'event',
#   'control',
#   'architecture',
#   'system',
#   'deadlock',
#   'avoidance',
#   'resource',
#   'allocation',
#   'system',
#   'resource',
#   'acquisition',
#   'routings',
#   'fidelity',
#   'prototyping',
#   'mm',
#   'fabs',
#   'event',
#   'system',
#   'correction',
#   'run',
#   'dap',
#   'ra',
#   'complexity',
#   'deadlock',
#   'avoidance',
#   'policy',
#   'resource',
#   'allocation',
#   'system',
#   'synthesis',
#   'deadlock',
#   'avoidance',
#   'policy',
#   'resource',
#   'allocation',
#   'system',
#   'event',
#   'control',
#   'framework',
#   'system',
#   'voice',
#   'conversion',
#   'intonation',
#   'auto',
#   'encoder',
#   'word',
#   'rnn',
#   'baseline',
#   'sentence',
#   'completion',
#   'training',
#   'level',
#   'network',
#   'speaker',
#   'identification',
#   'verification',
#   'sequence',
#   'model',
#   'greedy',
#   'grapheme',
#   'conversion',
#   'text',
#   'gender',
#   'classification',
#   'approach',
#   'reinforcement',
#   'factory',
#   'operation',
#   'inference',
#   'smartphone',
#   'sensor',
#   'data',
#   'model',
#   'classification',
#   'user',
#   'sensor',
#   'semi',
#   'inattention',
#   'prediction',
#   'framework',
#   'vehicle',
#   'distance',
#   'approach',
#   'place',
#   'trajectory',
#   'data',
#   'schedule',
#   'phase',
#   'method',
#   'tire',
#   'production',
#   'planning',
#   'problem',
#   'instant',
#   'planning',
#   'case',
#   'semi',
#   'method',
#   'inattention',
#   'prediction',
#   'machine',
#   'interaction',
#   'system',
#   'prediction',
#   'role',
#   'playing',
#   'game',
#   'markov',
#   'model',
#   'feature',
#   'item',
#   'approach',
#   'construction',
#   'price',
#   'comparison',
#   'shopping',
#   'service',
#   'class',
#   'text',
#   'classification',
#   'performance',
#   'support',
#   'vector',
#   'machine',
#   'classifier',
#   'event',
#   'detection',
#   'stream',
#   'disaster',
#   'management',
#   'pattern',
#   'tree',
#   'kernel',
#   'text',
#   'classification',
#   'model',
#   'sequence',
#   'data',
#   'classification',
#   'svm',
#   'keyword',
#   'extraction',
#   'microblogs',
#   'time',
#   'search',
#   'engine',
#   'retrieval',
#   'medium',
#   'time',
#   'challenge',
#   'search',
#   'text',
#   'mining',
#   'retrieval',
#   'model',
#   'information',
#   'discovery',
#   'time',
#   'svm',
#   'approach',
#   'selection',
#   'relevance',
#   'judgement',
#   'feed',
#   'time',
#   'road',
#   'function',
#   'set',
#   'topic',
#   'coverage',
#   'tag',
#   'similarity',
#   'computation',
#   'term',
#   'space',
#   'dimension',
#   'reduction',
#   'study',
#   'measurement',
#   'model',
#   'business',
#   'performance',
#   'interface',
#   'business',
#   'technology',
#   'roadmap',
#   'field',
#   'study',
#   'icon',
#   'communication',
#   'interaction',
#   'incorporation',
#   'preference',
#   'service',
#   'conversation',
#   'approach',
#   'business',
#   'performance',
#   'monitoring',
#   'analysis',
#   'time',
#   'communication',
#   'support',
#   'building',
#   'world',
#   'game',
#   'community',
#   'event',
#   'peer',
#   'process',
#   'enactment',
#   'web',
#   'service',
#   'device',
#   'preference',
#   'profile',
#   'web',
#   'service',
#   'conversation',
#   'environment',
#   'extraction',
#   'conversation',
#   'protocol',
#   'choreography',
#   'specification',
#   'web',
#   'service',
#   'eca',
#   'rule',
#   'description',
#   'language',
#   'service',
#   'event',
#   'coordination',
#   'rule',
#   'web',
#   'service',
#   'device',
#   'environment',
#   'conversation',
#   'preference',
#   'profile',
#   'web',
#   'service',
#   'xpia',
#   'bpm',
#   'framework',
#   'process',
#   'improvement',
#   'business',
#   'process',
#   'generation',
#   'conversation',
#   'protocol',
#   'preference',
#   'service',
#   'conversation',
#   'web',
#   'service',
#   'transaction',
#   'protocol',
#   'pc',
#   'thp',
#   'w',
#   'cpp',
#   'web',
#   'service',
#   'conversation',
#   'preference',
#   'profile',
#   'approach',
#   'stock',
#   'trading',
#   'agent',
#   'performance',
#   'protocol',
#   'execution',
#   'web',
#   'service',
#   'advance',
#   'web',
#   'service',
#   'composition',
#   'implication',
#   'business',
#   'process',
#   'integration',
#   'composition',
#   'co',
#   'business',
#   'xslt',
#   'framework',
#   'peer',
#   'interaction',
#   'business',
#   'design',
#   'hold',
#   'protocol',
#   'coordination',
#   'multi',
#   'business',
#   'transaction',
#   'allocation',
#   'web',
#   'service',
#   'protocol',
#   'deadlock',
#   'livelock',
#   'co',
#   'allocation',
#   'resource',
#   'internet',
#   'supervision',
#   'resource',
#   'allocation',
#   'system',
#   'state',
#   'event',
#   'fidelity',
#   'simulator',
#   'mm',
#   'wafer',
#   'fabs',
#   'algebraic',
#   'deadlock',
#   'avoidance',
#   'policy',
#   'resource',
#   'allocation',
#   'system',
#   'net',
#   'approach',
#   'design',
#   'mm',
#   'wafer',
#   'fab',
#   'controller',
#   'complexity',
#   'deadlock',
#   'avoidance',
#   'policy',
#   'resource',
#   'allocation',
#   'system',
#   'resource',
#   'acquisition',
#   'routings',
#   'fidelity',
#   'prototyping',
#   'time',
#   'operation',
#   'event',
#   'system',
#   'specification',
#   'approach',
#   'software',
#   'control',
#   'fidelity',
#   'factory',
#   'flexibility',
#   'deadlock',
#   'avoidance',
#   'policy',
#   'analysis',
#   'petri',
#   'net',
#   'design',
#   'deadlock',
#   'avoidance',
#   'policy',
#   'resource',
#   'allocation',
#   'system',
#   'integration',
#   'performance',
#   'control',
#   'manufacturing',
#   'analysis',
#   'deadlock',
#   'avoidance',
#   'unit',
#   'resource',
#   'allocation',
#   'system',
#   'event',
#   'control',
#   'approach',
#   'cell',
#   'system',
#   'design',
#   'control',
#   'system',
#   'agent',
#   'architecture',
#   'strategy',
#   'coordination',
#   'environment',
#   'development',
#   'application',
#   'builder',
#   'object',
#   'framework',
#   'object',
#   'time',
#   'executive',
#   'control',
#   'manufacturing',
#   'system']]

# %% [markdown]
# ## Tokenize abstract corpus

# %%
abs_tokens = []

for content in tqdm(abstract):
    t = gensim.utils.simple_preprocess(content)
    abs_tokens.append(t)
abs_pos_tokens = []
pos_list = ['NN','NNS','NNP','NNPS']
for sublist in tqdm(abs_tokens):
    temp = nltk.pos_tag(sublist)
    temp = [i for i in temp if i[1] in pos_list]
    abs_pos_tokens.append(temp)

abs_final_tokens = []

for sublist in abs_pos_tokens:
    temp=[]
    for item in sublist:
        t = lem.lemmatize(item[0], pos='n')
        temp.append(t)
    abs_final_tokens.append(temp)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████| 202/202 [00:00<00:00, 8439.58it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████| 202/202 [00:00<00:00, 292.27it/s]

# %% [markdown]
# # Build tagged corpus

# %%
for doc in abs_final_tokens:
    final_tokens.append(doc)

# %%
tagged_data = [TaggedDocument(words=_d, tags=[str(i)]) for i, _d in enumerate(final_tokens[:4])]

# %%
abs_tagger = [TaggedDocument(words=_d, tags=['abs'+str(i)]) for i, _d in enumerate(final_tokens[4:])]
for doc in abs_tagger:
    tagged_data.append(doc)

# %%
len(tagged_data) # 4 lab + 202 abstracts
# Out:
# 206

# %%
max_epochs = 100
vec_size = 100
alpha = 0.025

model = Doc2Vec(size=vec_size,
                alpha=alpha, 
                min_alpha=0.00025,
                min_count=1,
                dm =1)
  
model.build_vocab(tagged_data)

for epoch in range(max_epochs):
    if epoch % 10 ==9:
        print('iteration {0}'.format(epoch+1))
    model.train(tagged_data,
                total_examples=model.corpus_count,
                epochs=model.iter)
    # decrease the learning rate
    model.alpha -= 0.0002
    # fix the learning rate, no decay
    model.min_alpha = model.alpha
# Out:
# iteration 10
# iteration 20
# iteration 30
# iteration 40
# iteration 50
# iteration 60
# iteration 70
# iteration 80
# iteration 90
# iteration 100

# %% [markdown]
# ### 특정 lab. 과 가장 유사한 단어 벡터

# %%
doc1 = model.docvecs['1']
model.similar_by_vector(doc1)
# Out:
# [('optimization', 0.4897495210170746),
#  ('population', 0.48179152607917786),
#  ('payment', 0.45475950837135315),
#  ('elssp', 0.4447600841522217),
#  ('lnai', 0.4429042935371399),
#  ('logistics', 0.4420936107635498),
#  ('programming', 0.43970799446105957),
#  ('fcd', 0.43673911690711975),
#  ('setup', 0.42975914478302),
#  ('supplier', 0.4212070107460022)]

# %%
doc2 = model.docvecs['2']
model.similar_by_vector(doc2)
# Out:
# [('rank', 0.7109458446502686),
#  ('max', 0.6564980149269104),
#  ('train', 0.6179179549217224),
#  ('atm', 0.6132557392120361),
#  ('handelman', 0.6125264763832092),
#  ('configuration', 0.6064706444740295),
#  ('cut', 0.5906915068626404),
#  ('approximation', 0.5770852565765381),
#  ('axis', 0.5629941821098328),
#  ('multicast', 0.560961902141571)]

# %%
doc3 = model.docvecs['3']
model.similar_by_vector(doc3)
# Out:
# [('heterogenity', 0.5326517224311829),
#  ('precision', 0.5017560720443726),
#  ('leone', 0.4205802083015442),
#  ('grapheme', 0.41912612318992615),
#  ('bb', 0.41466397047042847),
#  ('execute', 0.412802129983902),
#  ('directive', 0.41278401017189026),
#  ('factory', 0.412083238363266),
#  ('momentum', 0.4105476140975952),
#  ('future', 0.4076741337776184)]

# %%
doc0 = model.docvecs['0']
model.similar_by_vector(doc0)
# Out:
# [('misstatement', 0.4721144735813141),
#  ('verification', 0.4721129834651947),
#  ('detection', 0.42952078580856323),
#  ('clad', 0.4235228896141052),
#  ('self', 0.41090112924575806),
#  ('cortex', 0.40609434247016907),
#  ('secure', 0.40481600165367126),
#  ('learning', 0.40409040451049805),
#  ('laminate', 0.3999432623386383),
#  ('observation', 0.3956422209739685)]

# %%
word_vec =model['support']
model.docvecs.most_similar([word_vec])
# Out:
# [('abs111', 0.2729227542877197),
#  ('abs16', 0.27022090554237366),
#  ('abs106', 0.2666151225566864),
#  ('abs7', 0.2567080855369568),
#  ('abs23', 0.2405010312795639),
#  ('abs173', 0.23998074233531952),
#  ('abs112', 0.23302768170833588),
#  ('abs123', 0.230605348944664),
#  ('abs91', 0.225291907787323),
#  ('abs68', 0.22120696306228638)]

# %% [markdown]
# ### Dict for abstracts

# %%
import pickle
with open('corpus.pkl','rb') as file:
    corpus = pickle.load(file)

# %%
corpus = [item for sublist in corpus for item in sublist]

# %%
corpus
# Out:
# ['The Effect of Naive Reinforcement Learning in the Stock Market\n',
#  'Product failure prediction with missing data\n',
#  'Stock Price Prediction Through Sentiment Analysis of Corporate Disclosures Using Distributed Representation\n',
#  'Applying convolution filter to matrix of word-clustering based document representation\n',
#  'Knowledge Extraction and Visualization of Digital Design Process\n',
#  'De-noising documents with a novelty detection method utilizing class vectors in customer-voice classification\n',
#  'Smartphone user segmentation based on app usage sequence with deep neural networks\n',
#  'Building Industry Network Based on Business Text: Corporate Disclosures and News\n',
#  'Machine learning-based anomaly detection via integration of manufacturing, inspection and after-sales service data\n',
#  'Bag-of-Concepts: Comprehending Document Representation through Clustering Words in Distributed Representation\n',
#  'Reliable prediction of anti-diabetic drug failure with a reject option\n',
#  'Mining the relationship between production and customer service data for failure analysis of industrial products\n',
#  'Virtual Metrology for Copper-Clad Laminate Manufacturing\n',
#  'Obtaining calibrated probability by ROC Binning\n',
#  'Box-office forecasting based on sentiments of movie reviews and independent subspace method\n',
#  'Efficient Feature Selection based on Random Forward Search for Virtual Metrology Modeling\n',
#  'Detecting financial misstatements with fraud intention using multi-class cost-sensitive learning\n',
#  'Semi-supervised support vector regression based on self-training with label uncertainty: An application to virtual metrology in semiconductor manufacturing\n',
#  'Energy-saving decision making framework for HVAC with usage logs\n',
#  'A Study on the Man-hour Prediction System for Shipbuilding\n',
#  'Optimal construction of one-against-one classifier based on meta-learning\n',
#  'Using wafer map features to better predict die-level failures in final test\n',
#  'Estimating the minority class proportion with the ROC curve using Military Personality Inventory data of the ROK Armed Forces\n',
#  'Multi-class classification via heterogeneous ensemble of one-class classifiers\n',
#  'A novel multi-class classification algorithm based on one-class support vector machine\n',
#  'Keystroke dynamics-based user authentication using long and free text strings from various input devices\n',
#  'An efficient and effective ensemble of support vector machines for anti-diabetic drug failure prediction\n',
#  'Memory die clustering and matching for optimal voltage window in semiconductor\n',
#  '추천 시스템 기법 연구동향 분석\n',
#  'Selecting an Optimal Set of Keywords for Search Engine Advertising\n',
#  'Improvement of virtual metrology performance by removing metrology noises in a training dataset\n',
#  'Constructing a multi-class classifier using one-against-one approach with different binary classifiers\n',
#  'KR-WordRank: A Korean word extraction method based on WordRank and unsupervised learning\n',
#  'Evaluating the reliability level of virtual metrology results for flexible process control: A novelty detection-based approach\n',
#  'Approximating support vector machine with artificial neural network for fast prediction\n',
#  'Probabilistic local reconstruction for k-NN regression and its application to virtual metrology in semiconductor manufacturing\n',
#  'Data based segmentation and summarization for sensor data in semiconductor manufacturing\n',
#  'Knowledge discovery in inspection reports of marine structures\n',
#  'Fast Parameterless Ballistic Launch Point Estimation based on k-NN Search\n',
#  'Multivariate Control Charts Based on Hybrid Novelty Scores\n',
#  'Stratified Sampling Design Based on Data Mining\n',
#  'Organizational tenure diversity as predictors of combat performance in ROK army\n',
#  'Mining transportation logs for understanding the after-assembly block manufacturing process in the shipbuilding industry\n',
#  'Pattern selection for support vector regression based response modeling\n',
#  'Support Vector Class Description (SVCD): Classification in Kernel Space\n',
#  'Improved response modeling based on Clustering, Under-sampling, and Ensemble\n',
#  'Machine learning-based novelty detection for faulty wafer detection in semiconductor manufacturing\n',
#  'Virtual metrology for run-to-run control in semiconductor manufacturing\n',
#  'Semi-Supervised Response Modeling\n',
#  'Account Sharing Detection through Keystroke Dynamics Analysis\n',
#  'A virtual metrology system for semiconductor manufacturing\n',
#  'A hybrid novelty score and its use in keystroke dynamics-based user authentication\n',
#  'Improving authentication accuracy using artificial rhythms and cues for keystroke dynamics-based authentication\n',
#  'Keystroke dynamics-based authentication for mobile devices\n',
#  'Locally linear reconstruction for instance-based learning\n',
#  'Improvement of keystroke data quality through artificial rhythms and cues\n',
#  'Bootstrap based pattern selection for support vector regression\n',
#  'Supporting diagnosis of attention-deficit hyperactive disorder with novelty detection\n',
#  'Response modeling with support vector regression\n',
#  'Clustering-based reference set reduction for k-nearest neighbor\n',
#  'Continual retraining of keystroke dynamics based authenticator\n',
#  'Retraining a keystroke dynamics-based authenticator with impostor patterns\n',
#  'Focusing on non-respondents: Response modeling with novelty detectors\n',
#  'Neighborhood property based pattern selection for support vector machines\n',
#  'The novelty detection approach for different degrees of class imbalance\n',
#  'EUS SVMs: ensemble of under-sampled SVMs for data imbalance problems\n',
#  'e-tube Based Pattern Selection for Support Vector Machines\n',
#  'Improving Authentication Accuracy of Unfamiliar Passwords with Pauses and Cues for Keystroke Dynamics Based Authentication\n',
#  'The Effectiveness of Artificial Rhythms and Cues in Keystroke Dynamics based User Authentication\n',
#  'Application of LVQ to Novelty Detection Using Outliers in Training Data \n',
#  'Ensemble based on GA Wrapper Feature Selection\n',
#  'Response Modeling with Suppport Vector Machines\n',
#  'Constructing Response Model using Ensemble based on Feature Subset Selection\n',
#  'Data Mining Problems and Solutions for Response Modeling in CRM\n',
#  'GA SVM Wrapper Ensemble for Keystroke Dynamics Authentication\n',
#  'Classification of Bluffing Behavior and Affective Attitude from Prefrontal Surface Encephalogram during On-line Game\n',
#  'Retraining a Novelty Detector with Impostor Patterns for Keystroke Dynamics Based Authentication\n',
#  'Artificial Rhythms and Cues for Keystroke Dynamics Based Authentication\n',
#  'SOM-based Novelty Detection using Novel Data\n',
#  'Invariance of Neighborhood Relation under Input Space to Feature Space Mapping\n',
#  'Response Models Based on Bagging Neural Networks\n',
#  'Combining Gaussian Mixture Models\n',
#  'Keystroke Dynamics Identity Verification - its problems and practical solutions\n',
#  'Fast Pattern Selection Algorithm for Support Vector Classifiers: Time Complexity Analysis\n',
#  'Novelty Detection Approach for Keystroke Dynamics Identity Verification\n',
#  'Fast Pattern Selection for Support Vector Classifiers\n',
#  'A Study on Rainfall-Runoff Models for Improving Ensemble Streamflow Prediction: 1. Rainfall-runoff Models Using Artificial Neural Networks\n',
#  'An Up-trend Detection using an Auto-Associative Neural Network: KOSPI200 Futures\n',
#  'Pattern Selection for Support Vector Classifiers\n',
#  'Observational Learning Algorithm for an Ensemble of Neural Networks\n',
#  'Smoothed Bagging with Kernel Bandwidth Selectors\n',
#  'Observational Learning with Modular Networks\n',
#  'Left-shoulder Detection in Korea Composite Stock Price Index using an Auto-Associative Neural Network\n',
#  'Web based Keystroke Dynamics Identity Verification using Neural Network\n',
#  'Multiple permeability predictions using observational learning algorithm\n',
#  'Constructing Belief Networks from Realistic Data\n',
#  'A Neural Network Method for Diagnosing Beam Position Monitors in Storage Ring\n',
#  'Belt Speed Control in Sintering Plant using Neural Networks\n',
#  'Spatial Interpolation using Artificial Neural Network\n',
#  'Reliable Roll Force Prediction in Cold Mill using Multiple Neural Networks\n',
#  'Virtual Sample Generation using a Population of Networks\n',
#  'Does Rotation of Neuronal Population Vectors Equal Mental Rotation?\n',
#  'Hybrid Neural-Network/Mathematical Prediction Model for Tandem Cold Mill\n',
#  'Design Guidelines for Character Rejection and Substitution for Off-line Document Processing Systems\n',
#  'Effects of varying parameters on properties of self-organizing maps\n',
#  'Map Formation in Proprioceptive Cortex\n',
#  'Multiple Disorder Diagnosis with Adaptive Competitive Neural Networks\n',
#  'Learning Competition and Cooperation\n',
#  "Improvement of Kittler and Illingworth's Minimum Error Thresholding",
#  'Stochastic Facility Location Model for Drones Considering Uncertain Flight Distances\n',
#  'Dynamic vs. Static Rebates: an Investigation on Price, Displayed Stock Level, and Rebate-induced Demand Using a Hybrid Bat Algorithm\n',
#  'Wartime logistics model for multi-support unit location-allocation problem with front line changes\n',
#  'Joint Pricing and Inventory Decisions with Carbon Emission Considerations, Partial Backordering and Planned Discounts\n',
#  'Investment and Coordination Decisions in a Supply Chain of Fresh Agricultural Products\n',
#  'Task Scheduling System for UAV Operations in Indoor Environment\n',
#  'Integrated Optimal Scheduling of Repair Crew and Relief Vehicle after Disaster\n',
#  'Hybrid NSGA-II Algorithm for an Imperfect Production System Considering Product Quality and Returns under Two Warranty Policies\n',
#  'Traveling Salesman Problem with a Drone Station\n',
#  'Network Repair Crew Scheduling for Short-Term Disasters\n',
#  'Medical Relief Shelter Location Problem with Patient Severity under a Limited Relief Budget\n',
#  'Range-based Truck-state Transition Modeling Method for Foldable Container Drayage Services\n',
#  'Direct Shipping Service Routes with an Empty Container Management Strategy\n',
#  'Balancing a Mixed-model Assembly Line with Unskilled Temporary Workers: Algorithm and Case Study\n',
#  'Early Stage Response Problem for Post-Disaster Incidents\n',
#  'Pricing, product quality, and collection optimization in a decentralized closed-loop supply chain with different channel structures: Game theoretical approach\n',
#  'The Impact of Online Sales on Centralised and Decentralised Dual-channel Supply Chains\n',
#  'Strategic Inventory: Manufacturer vs. Retailer Investment\n',
#  'Supply Chain Coordination with a Single Supplier and Multiple Retailers considering Customer Arrival Times and Route Selection\n',
#  'Joint Decisions on Product Line Selection, Purchasing, and Pricing\n',
#  'Optimal Decisions of Price, Quality, Effort Level and Return Policy in a Three-level Closed-loop Supply Chain based on Different Game Theory Approaches\n',
#  'Warehouse Capacity Sharing via Transshipment for an Integrated Two-echelon Supply Chain\n',
#  'An Integer Program and a Hybrid Genetic Algorithm for the University Timetabling Problem\n',
#  'Optimal Retailer Investments in Green Operations and Preservation Technology for Deteriorating Items\n',
#  'Fuzzy Bi-objective Production-Distribution Planning Problem under the Carbon Emission Constraint\n',
#  'The Distribution-free Newsboy Problem with Multiple Discounts and Upgrades\n',
#  'Multi-Depot Vehicle Routing Problem with Time Windows considering Delivery and Installation Vehicles\n',
#  'Evolutionary Resource Assignment for Workload-based Production Scheduling\n',
#  'Dual channel closed-loop supply chain coordination with a reward-driven remanufacturing policy\n',
#  'Repositioning of Empty Containers using both Standard and Foldable Containers\n',
#  'Supply Chain Coordination under Budget Constraints\n',
#  'Hybrid Genetic Algorithms for the Three-dimensional Multiple Container Packing Problem\n',
#  'Channel Coordination for Multi-stage Supply Chains with Revenue-sharing Contracts under Budget Constraints\n',
#  'A Combined Tramp Ship Routing, Fleet Deployment, and Network Design Problem\n',
#  'Manufacturing Setup Cost Reduction and Quality Improvement for the Distribution Free Continuous-review Inventory Model with a Service Level Constraint\n',
#  'Labour Productivity in Modular Assembly: A Study of Automotive Module Suppliers\n',
#  'Container Packing Problem with Balance Constraints\n',
#  'A Network Flow Model for the Optimal Allocation of both Foldable and Standard Containers\n',
#  'Improved Quality, Setup Cost Reduction, and Variable Backorder Costs in an Imperfect Production Process\n',
#  'A Hybrid Hub-and-Spoke Postal Logistics Network with Realistic Restrictions: A Case Study of Korea Post\n',
#  'Planning of Business Process Execution in Business Process Management Environments\n',
#  'Modeling and Optimization of Energy Efficient Routing in Wireless Sensor Networks\n',
#  'Economic Lot and Supply Scheduling Problem: A Time-varying Lot Sizes Approach\n',
#  'Hybrid Genetic Algorithms for Test Bed Scheduling Problems\n',
#  'Min-max Distribution Free Continuous-review Model with a Service Level Constraint and Variable Lead Time\n',
#  'Revenue-sharing Contracts in an N-stage Supply Chain with Reliability Considerations\n',
#  'A Pick-up and Delivery Service Network Design among Service Centers for Low Demands in Express Delivery Services\n',
#  'A Decision Making Model for Strategic Alliance-based Network Design in Express Delivery Services\n',
#  'A Fractal Echelon Approach for Inventory Management in Supply Chain Networks\n',
#  'Foldable and Standard Containers in Empty Container Repositioning\n',
#  'Vehicle Routing Problem with Time Windows considering Overtime and Outsourcing Vehicles\n',
#  'A Hybrid Genetic Algorithm with a new Packing Strategy for the Three-dimensional Bin Packing Problem\n',
#  'A Memetic Particle Swarm Optimization Algorithm for Multimodal Optimization Problems\n',
#  'Flexible Job-shop Scheduling Problems with ‘AND’/‘OR’ Constraints\n',
#  'Inventory Systems with Variable Capacity\n',
#  'The Storage Capacity Expansion and Space Leasing for Container Depots\n',
#  'Modeling and Optimization of a Container Drayage Problem with Resource Constraints\n',
#  'The Joint Replenishment and Freight Consolidation of a Warehouse in a Supply Chain\n',
#  'An EPQ Model with Inflation in an Imperfect Production System\n',
#  'Collaborative Fractal-based Supply Chain Management Based on a Trust Model for the Automotive Industry\n',
#  'Positioning Empty Containers among Multiple Ports with Leasing and Purchasing Considerations\n',
#  'Multi-level Supply Chain Network Design with Routing\n',
#  'A Reactive Tabu Search Algorithm for the Multi-Depot Container Truck Transportation Problem\n',
#  'Integrated Assembly Line Balancing with Resource Restrictions\n',
#  'Offsetting Inventory Cycles using Mixed Integer Programming and Genetic Algorithm\n',
#  'The Joint Replenishment and Delivery Scheduling of the One-Warehouse, n-Retailer System\n',
#  'Analytic Hierarchy Process to Assess and Optimize Distribution Network\n',
#  'Simulation-based Maintenance Support System for Multi-functional Complex Systems\n',
#  'The Joint Replenishment Problem Involving Multiple Suppliers Offering Quantity Discounts\n',
#  'Genetic Algorithms for Job Shop Scheduling Problems with Alternative Routings\n',
#  'Hybrid Genetic Algorithm for Group Technology Economic Lot Scheduling Problem\n',
#  'The Joint Replenishment Problem with Resource Restriction\n',
#  'Coordinated Inventory Models with Compensation Policy in a Three Level Supply Chain\n',
#  'A Simple Heuristic on a Multi-product Inventory System with Budgetary Constraint\n',
#  'The Joint Replenishment Problem with Quantity Discounts under Constant Demand\n',
#  'A Continuous Review Inventory Model with the Controllable Production Rate of the Manufacturer\n',
#  'Economic Order Quantity Models for Ameliorating/Deteriorating Items under Inflation and Time Discounting\n',
#  'Note on an Economic Lot Scheduling Problem under Budgetary and Capacity Constraints\n',
#  'Accounting for Idle Capacity Cost in the Scheduling of Economic Lot Sizes\n',
#  'Scheduling Economic Lot Sizes in Deteriorating Production Systems\n',
#  'Economic Lot Scheduling Problem with Imperfect Production Processes and Setup Times\n',
#  'Hybrid Genetic Algorithm for the Economic Lot-Scheduling Problem\n',
#  'Book Review: Inventory Management and Production Planning and Scheduling, third editon\n',
#  'Comment on Boss S, Goswami A and Chaudhuri KS(1995). An EOQ Model for Deteriorating Items with Linear Time-dependent Demand Rate and Shortages under Inflation and Time Discounting\n',
#  'The Multi-Item Single Period Problem with an Initial Stock of Convertible Units\n',
#  'Multi-Item Economic Order Quantity Model with an Initial Stock of Convertible Units\n',
#  'Minimizing the Expected Total Value of Shortages for a Population of Items Subject to Practical Restrictions on the Reorder Points\n',
#  'The Effects of Inflation and Time-Value of Money on an Economic Order Quantity Model with a Random Product Life Cycle\n',
#  'The Multi-Item Newsvendor Problem with a Budget Constraint and Fixed Ordering Costs\n',
#  'A Fast Heuristic for Minimizing Total Average Cycle Stock Subject to Practical Constraints\n',
#  'The Effect of the Stabilization Period on The Economic Lot Scheduling Problem\n',
#  'A Note on Lead Time and Distributional Assumptions in Continuous Review inventory Models\n',
#  'Rationing Policies for Some Inventory Systems\n',
#  'Warranty Cost Analysis under Continuous Sales\n',
#  'The Distribution Free Job Control Problem\n',
#  'Distribution Free Procedures for Make-to-Order(MTO), Make-in-Advance(MIA), and Composite Policies\n',
#  'System Analysis of a Multi-Product, Small-Lot-Sized Production by Simulation : A Korean Motor Factory Case\n',
#  "How to Avoid Stockouts When Producing Several Items on a Single Facility? What to Do if You Can't?\n",
#  'Strategic Investment to Reduce Setup Time in the Economic Lot Scheduling Problem\n',
#  'The Distribution Free Newsboy Problem with Balking\n',
#  'Generalized Fomula for the Periodic Geometric-Gradient Series Payment in a Skip Payment Loan with Arbitrary Skips\n',
#  'The Distribution Free Continuous Review Inventory System with a Service Level Constraint\n',
#  'Multiproduct Economic Lot Size Models with Investment Costs for Setup Reduction and Quality Improvement : Review and Extensions\n',
#  'Distribution Free Procedures for Some Inventory models\n',
#  'Optimal Control of a Manufacturing Process that Involves Trial Runs\n',
#  'An Economic Order Quantity Model with a Random Planning Horizon\n',
#  'A Note on Evaluating Investments in Inventory System : A Net Present Value Framework\n',
#  'A Note of Correction on Multi-Product Scheduling on a Single Machine\n',
#  'The Distribution Free Newsboy Problem : Review and Extensions\n',
#  'A Note on Impact to Investing in Quality Improvement on the Lot Size Model\n',
#  'The Effect of Externalizing Setups in the Economic Lot Scheduling Problem\n',
#  'Controllable Production Rates in a Family Production Context',
#  "A randomized nonatomic game model permitting inverse-optimization for estimating agents' heterogenity,\n",
#  'A precision pump schedule optimization for the water supply networks with small buffers,\n',
#  'A note on the strong polynomiality of convex quadratic programming,\n',
#  'About the strong polynomial time algorithms for quadratic optimization over submodular constraints,\n',
#  'On the complexity of the production-transportation problem,\n',
#  'An efficient multicast routing algorithm for delay-sensitive applications with dynamic membership,\n',
#  'A competitive online algorithm for the paging problem with "shelf" memory,\n',
#  'Towards real-time optimal VP management for ATM nets,\n',
#  'Efficient algorithms for the multicast trees packet-replication restrictions,\n',
#  'An optimal virtual topology configuration for multicast in ATM and MPLS networks,\n',
#  'A fully polynomial bicriteria approximation scheme for the constrained spanning tree problem,\n',
#  'Connection-level QoS provisioning in multiple transmission technology-based OFDM system,\n',
#  'Two-Server Network Disconnection Problem,\n',
#  'Approximability of the k-server disconnection problem,\n',
#  'Polynomiality of sparsest cuts with fixed number of sources,\n',
#  'A genetic algorithm for joint replenishment based on the exact inventory cost,\n',
#  'A pseudo-polynomial heuristic for path-constrained discrete-time markovian target search,\n',
#  'Unification of lower-bound analyses of the lift-and-project rank of combinatorial optimization polyhedra,\n',
#  'A pragmatic algorithm for the train-set routing : The case of Korea high-speed railway,\n',
#  'Optimal search-relocation trade-off in Markovian-target searching,\n',
#  'Approximation of k-batch consolidation problem,\n',
#  'Approximation of a Batch Consolidation Problem,\n',
#  'An appraisal of a column-generation-based algorithm for a centralized train-conflict resolution on metropolitan railway network,\n',
#  'Rank of Handelman Hierarchy for Max-Cut,\n',
#  'Handelman rank of zero-diagonal quadratic programs over a hypercube and its applications,\n',
#  'Column generation approach to line planning with various halting patterns - application to the Korean high-speed railway,\n',
#  'Optimization of the future soldier system: an integrative approach based on agent-based simulation and response surface method,\n',
#  'Does crowding affect the path choice of metro passengers?,\n',
#  'Mining missing train logs from Smart Card data,\n',
#  'Precise estimation of connections of metro passengers from Smart Card data,\n',
#  'Predicting express-train choice of metro passenger from Smart Card data,\n',
#  "A method to directly derive taste heterogeneity of travellers' route choice in public transport from observed routes,",
#  'A Case -Based Reasoning Approach to Fast Optimization of Travel Routes for Large Scale AS?/RSs\n',
#  'Learning to Dispatch Operations with Intentional Delay for Re-Entrant Multiple-Chip Product Assembly Lines\n',
#  '"A Semi-Supervised Inattention Detection Method Using Biological Signal\n',
#  'Laplace Based Approximate Posterior Inference for Differential Equation Models\n',
#  'An On-Device Gender Prediction Method for Mobile Users Using Representative Wordsets\n',
#  'Fast Scheduling of Semiconductor Manufacturing Facilities Using Case Based Reasoning\n',
#  'Next Place Prediction Based on Spatiotemporal Pattern Mining of Mobile Device Logs\n',
#  'Design Strategies for Idle Screens of Smartphones Based on Service Usages\n',
#  '?LiveGantt: Interactively Visualizing a Large Manufacturing Schedule\n',
#  'A Conditional Feature Utilization Approach to Itemset Retrieval in Online Shopping Services\n',
#  'Automatic Extraction of Persistent Topics from Social Text Streams\n',
#  'Setup Change Scheduling for Semiconductor Packaging Facilities Using a Genetic Algorithm with an Operator Recommender\n',
#  'Mobile Phone Purchase and Usage Behaviors of Early Adopter Groups in Korea\n',
#  'Hypovigilance Detection for UCAV Operators Based on a Hidden Markov Model,\n',
#  'A return on investment assessment model for a mobile user interface project at the predevelopment stage\n',
#  'Composition Pattern Oriented Tag Extraction from Short Documents Using a Structural Learning Method\n',
#  'Language Independent Semantic Kernels for Short-text Classification\n',
#  'Feature Identification for Topical Relevance Assessment in Feed Search Engines\n',
#  'Pricing Fraud Detection in Online Shopping Malls Using a Finite Mixture Model\n',
#  'Topic Based Photo Set Retrieval Using User Annotated Tags\n',
#  'Revenue Maximizing Itemset Construction for Online Shopping Services,\n',
#  'A Resource Allocation Policy for Delay Minimization in Fetching Capacitated Feeds,\n',
#  'Joint Optimization of Index Freshness and Coverage in Real-Time Search Engines\n',
#  'Discovery of Information Diffusion Process in Social Networks,\n',
#  'Online Video Recommendation Through Tag-Cloud Aggregation\n',
#  '?FlowWiki: A Wiki Based Platform for Ad-hoc Collaborative Workflows\n',
#  'Searching Social Media Streams on the Web\n',
#  'A Vector Space Approach to Tag Cloud Similarity Ranking\n',
#  'Exploring the Relationship between Keywords and Feed Elements in Blog Post Search\n',
#  'A Business Performance Measurement Model for Mobile User Interface\n',
#  'Hyperlinking the Work for Self-Management of Flexible Workflows\n',
#  'An ECA-Based Framework for Decentralized Coordination of Ubiquitous Web Services\n',
#  'A Multi-Agent Approach to Q-Learning for Daily Stock Trading\n',
#  'An Integrated Approach to Process-Driven Business Performance Monitoring and Analysis for Real-Time Enterprises\n',
#  'Incorporation of User Preferences into Mobile Web Service Conversations\n',
#  'An Adaptive Coordination Framework for Fast Atomic Multi-Business Transactions Using Web Services\n',
#  'A High Performance Backoff Protocol for Fast Execution of Composite Web Services\n',
#  'Communication Supports for Building World Wide Internet Game Communities\n',
#  'Event-based Peer-to-Peer Process Enactment for Ubiquitous Web Service Devices\n',
#  'Automatic Extraction of Conversation Protocols from a Choreography Specification of Ubiquitous Web Services\n',
#  'An XSLT Based Framework for Automating Peer-To-Peer Interactions Between Complex Business Processes\n',
#  'A Deadlock and Livelock Free Protocol for Decentralized Internet Resource Coallocation\n',
#  'A Protocol for Fast Co-Allocation of Shared Web Services\n',
#  'Policy Mixtures: A Novel Approach for Enhancing the Operational Flexibility of Resource Allocation Systems with Alternate Routings\n',
#  'Liveness-Enforcing Supervision for Resource Allocation Systems with Uncontrollable Behavior and Forbidden States\n',
#  'A Distributed, Event-Driven Control Architecture for Flexibly Automated Manufacturing Systems\n',
#  'Deadlock Avoidance in Sequential Resource Allocation Systems with Multiple Resource Acquisitions and Flexible Routings\n',
#  'High-Fidelity Rapid Prototyping of 300mm Fabs through Discrete Event Systems Modeling\n',
#  'Correction to the RUN DAP for Conjunctive RAS Presented in "Polynomial-Complexity Deadlock Avoidance Policies for Sequential Resource Allocation Systems"\n',
#  'Algebraic Synthesis of Efficient Deadlock Avoidance Policies for Sequential Resource Allocation Systems\n',
#  'A Generic Event Control Framework for Modular Flexible Manufacturing Systems\n',
#  'Voice Conversion with Diverse Intonation using Conditional Variational Auto-Encoder\n',
#  'Word RNN as a Baseline for Sentence Completion\n',
#  'TRAINING UTTERANCE-LEVEL EMBEDDING NETWORKS FOR SPEAKER IDENTIFICATION AND VERIFICATION\n',
#  'CONVOLUTIONAL SEQUENCE TO SEQUENCE MODEL WITH NON-SEQUENTIAL GREEDY DECODING FOR GRAPHEME TO PHONEME CONVERSION\n',
#  'Text Based Gender Classification Using Two Phase Approach\n',
#  'Deep Reinforcement Learning for Smart Factory Operation\n',
#  'Mobile context inference using multimodal smartphone sensor data\n',
#  'An ensemble model for gender classification of mobile users\n',
#  'EEG Sensor Based Semi-Supervised Inattention Prediction Framework for Unmanned Aerial Vehicles\n',
#  'A Spatio-Temporal Distance Based Clustering Approach for Discovering Significant Places from Trajectory Data\n',
#  '?LiveGantt: Interactively Visualizing a Large Manufacturing Schedule\n',
#  ' A Two-Phase Method for Solving Tire Production Planning Problem\n',
#  'Instant Planning with Case Based Reasoning\n',
#  'A semi-supervised attributes-weighting clustering method for inattention prediction in human-machine interaction systems\n',
#  'CHURN PREDICTION FOR A MASSIVELY MULTIPLAYER ONLINE ROLE-PLAYING GAME USING A HIDDEN MARKOV MODEL\n',
#  'A Feature-Based Item Ranking Approach to Itemset Construction in Price Comparison Shopping Services\n',
#  'Improving Multi-Class Text Classification Performance by Combining Support Vector Machine and Random Forest Classifiers\n',
#  'Bursty Event Detection from Text Streams for Disaster Management\n',
#  'Semantic Pattern Tree Kernels for Short-text Classification\n',
#  'A Hidden Markov Model for Sequence Data Classification\n',
#  'A Latent Structural SVM for Automatic Keyword Extraction from Microblogs\n',
#  'A Scalable Real-Time Search Engine for Fast Retrieval of Social Media Content,\n',
#  'Real-time web: new challenges in search and text mining\n',
#  'Retrieval Models for Information Discovery from Real-Time Web\n',
#  'An SVM Based Approach to Feature Selection for Topical Relevance Judgement of Feeds"\n',
#  'Real-Time Web Search: The Road Ahead\n',
#  'A Scoring Function for Retrieving Photo Sets with Broad Topic Coverage\n',
#  'Tag-based Object Similarity Computation Using Term Space Dimension Reduction\n',
#  'A Study on Measurements Model for the Business Performance in Mobile User Interface\n',
#  'Developing e-Business Technology Roadmap: A Field Study\n',
#  'Icon-based Communication for Global Interactions\n',
#  'Incorporation of User Preferences into Mobile Web Service Conversations\n',
#  'An Integrated Approach to Process-Driven Business Performance Monitoring and Analysis for Real-Time Enterprises\n',
#  'Communication Supports for Building World Wide Internet Game Communities\n',
#  'Event-based Peer-to-Peer Process Enactment for Ubiquitous Web Service Devices\n',
#  ' A Preference Profile for Automating Web Services Conversation in Mobile Environment\n',
#  'Automatic Extraction of Conversation Protocols from a Choreography Specification of Ubiquitous Web Services\n',
#  'WS-ECA: An ECA Rule Description Language for Ubiquitous Services Computing\n',
#  'Event-driven Coordination Rule of Web Services enabled Devices in Ubiquitous Environments\n',
#  'Conversation Preference Profile for Mobile Web Service\n',
#  'xPIA: A BPMS-Enabled Executable Framework for Continuous Process Improvement\n',
#  'Enhancing the Interoperability Between Business Processes through Automatic Generation of Conversation Protocols\n',
#  'Incorporating Preferences into Web Service Conversations\n',
#  'Designing an Efficient Web Service Transaction Protocol Using 2PC and THP\n',
#  'WS-CPP (Web Services Conversation Preference Profile)\n',
#  'A Q-Learning Based Approach to Design of Intelligent Stock Trading Agents\n',
#  'A High Performance Protocol for Fast Execution of Composite Web Services\n',
#  'Recent advances in web services composition and their implications to seamless business process integration\n',
#  'Towards the Automatic Composition of Co-Business Processes\n',
#  'An XSLT Based Framework for Automating Peer-To-Peer Interactions between Complex Business Processes\n',
#  'Design of an Efficient Tentative Hold Protocol for Automated Coordination of Multi-Business Transactions\n',
#  'A Protocol for Fast Co-Allocation of Shared Web Services\n',
#  'A Scalable Protocol for Deadlock and Livelock Free Co-Allocation of Resources in Internet Computing\n',
#  'Liveness Enforcing Supervision for Resource Allocation Systems with Forbidden States and Uncontrollable Events\n',
#  'A High-Fidelity, Web-Based Simulator for 300mm Wafer Fabs\n',
#  'Algebraic Deadlock Avoidance Policies for Conjunctive / Disjunctive Resource Allocation Systems\n',
#  'A Colored Petri Net-based Approach to the Design of 300mm Wafer Fab Controllers\n',
#  'A Polynomial-Complexity Deadlock Avoidance Policy for Sequential Resource Allocation Systems with Multiple Resource Acquisitions and Flexible Routings\n',
#  'High-Fidelity Rapid Prototyping of the Real-Time Fab Operations through Discrete Event System Modeling\n',
#  'A Formal Specification Approach to Design Generic Software for Control of High-Fidelity Virtual Factory\n',
#  'Enhancing the Flexibility of Algebraic Deadlock Avoidance Policies through Petri Net Structural Analysis\n',
#  'Petri Net Based Design of Efficient Deadlock Avoidance Policies for Sequential Resource Allocation Systems\n',
#  'Integration of Structural and Performance-Oriented Control in Flexibly Automated Manufacturing\n',
#  'Petri Net Structural Analysis and Deadlock Avoidance in Single-Unit Resource Allocation Systems\n',
#  'A Discrete Event Control Approach to Robotic Cell Operating System Design\n',
#  'Distributed Control of Automated Manufacturing Systems in an Agent-Based Architecture\n',
#  'FMS Scheduling Strategies in a Distributed Coordination Environment\n',
#  'Development of Integrated Configurable Application Builder based on Object-Oriented Framework\n',
#  'An Object-Based Run-Time Executive for Control of Flexible Manufacturing Systems']

# %%
abs_dct = {}
for i in range(len(corpus)):
    abs_dct[i] = corpus[i]

# %%
abs_dct.get(35)
# Out:
# 'Probabilistic local reconstruction for k-NN regression and its application to virtual metrology in semiconductor manufacturing\n'

# %% [markdown]
# ### Lab. 0 ('DM') 와 가장 유사한 논문

# %%
dct
# Out:
# {0: 'dm', 1: 'scm', 2: 'polytope', 3: 'imlab'}

# %%
similar_doc = model.docvecs.most_similar('0')
print(similar_doc)
# Out:
# [('abs44', 0.3526928424835205), ('abs47', 0.3400379717350006), ('abs46', 0.3288889527320862), ('abs35', 0.3200221061706543), ('abs87', 0.315833181142807), ('abs16', 0.31565016508102417), ('abs104', 0.3156258463859558), ('abs8', 0.30993974208831787), ('abs81', 0.30904173851013184), ('abs86', 0.30123087763786316)]

# %%
# 이들의 제목은?
for i in similar_doc:
    key_ = i[0][3:]
    print(key_)
    print(abs_dct.get(int(key_)))
# Out:
# 44
# Support Vector Class Description (SVCD): Classification in Kernel Space
#
# 47
# Virtual metrology for run-to-run control in semiconductor manufacturing
#
# 46
# Machine learning-based novelty detection for faulty wafer detection in semiconductor manufacturing
#
# 35
# Probabilistic local reconstruction for k-NN regression and its application to virtual metrology in semiconductor manufacturing
#
# 87
# An Up-trend Detection using an Auto-Associative Neural Network: KOSPI200 Futures
#
# 16
# Detecting financial misstatements with fraud intention using multi-class cost-sensitive learning
#
# 104
# Effects of varying parameters on properties of self-organizing maps
#
# 8
# Machine learning-based anomaly detection via integration of manufacturing, inspection and after-sales service data
#
# 81
# Combining Gaussian Mixture Models
#
# 86
# A Study on Rainfall-Runoff Models for Improving Ensemble Streamflow Prediction: 1. Rainfall-runoff Models Using Artificial Neural Networks

# %% [markdown]
# ### Lab. 3 ('Imlab') 와 가장 유사한 논문

# %%
# 이들의 제목은?
similar_doc = model.docvecs.most_similar('3')
for i in similar_doc:
    key_ = i[0][3:]
    print(key_)
    print(abs_dct.get(int(key_)))
# Out:
# 201
# Rationing Policies for Some Inventory Systems
#
# 24
# A novel multi-class classification algorithm based on one-class support vector machine
#
# 196
# The Effects of Inflation and Time-Value of Money on an Economic Order Quantity Model with a Random Product Life Cycle
#
# 32
# KR-WordRank: A Korean word extraction method based on WordRank and unsupervised learning
#
# 189
# Economic Lot Scheduling Problem with Imperfect Production Processes and Setup Times
#
# 92
# Left-shoulder Detection in Korea Composite Stock Price Index using an Auto-Associative Neural Network
#
# 179
# Hybrid Genetic Algorithm for Group Technology Economic Lot Scheduling Problem
#
# 44
# Support Vector Class Description (SVCD): Classification in Kernel Space
#
# 56
# Bootstrap based pattern selection for support vector regression
#
# 159
# Vehicle Routing Problem with Time Windows considering Overtime and Outsourcing Vehicles
